# %%
import os, yaml, sys
import cv2
import numpy as np
import torch
import matplotlib.pyplot as plt
from ultralytics import YOLO
from IPython.display import clear_output
# %matplotlib inline

ENV = os.getenv("MY_ENV", "dev")
with open("../../config.yaml", "r") as f:
    config = yaml.safe_load(f)
paths = config[ENV]["paths"]
sys.path.append(paths["src_path"])
from image_processing.utils import read_video
from image_processing.computational_models import detect_faces, make_corners

# %%
from huggingface_hub import hf_hub_download
face_model_path = hf_hub_download(repo_id="arnabdhar/YOLOv8-Face-Detection", filename="model.pt")
face_model = YOLO(face_model_path)
person_model_path = 'yolov8n.pt'
person_model = YOLO(person_model_path)

# %%
from ultralytics import YOLO

# Load the model
model = YOLO("yolov8n.pt")  # or your custom weights

# Print class labels
print(model.names)
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}

# %%
video_dir = f"{paths['livingstone_lab']}/Stimuli/Movies/all_videos"
video_fn = os.listdir(video_dir)

# %%
people_vids = [fn for fn in video_fn if ("IMG" not in fn) and ("YDX" not in fn)]

# %%
monkey_vids = [fn for fn in video_fn if "IMG" in fn]

# %%
ydx_vids = [fn for fn in video_fn if "YDX" in fn]

# %%
fn = "stevetoalle.mp4"
v = read_video(paths, 1, fn, vid_duration=0)
# Out:
# 16:03:47 - rank 1 stevetoalle.mp4 read successfully

# %%
coords = detect_faces(v, face_model, person_model, 1.5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Desktop/temporal_context/python_scripts/src/image_processing/computational_models.py:186, in detect_faces(video, face_model, person_model, scale)
#     185 try: # tries to detect a face with the face_model
# --> 186     x1, y1, x2, y2, confidence = compute_face_box(frame, face_model, scale=scale)
#     187     face_presence = 1 # face present
#
# File ~/Desktop/temporal_context/python_scripts/src/image_processing/computational_models.py:113, in compute_face_box(frame, face_model, scale)
#     112 if len(results[0].boxes) == 0:
# --> 113     raise IndexError("No detections found.")
#     114 confidence = round(results[0].boxes[0].conf[0].item(), 3)
#
# IndexError: No detections found.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 coords = detect_faces(v, face_model, person_model, 1.5)
#
# File ~/Desktop/temporal_context/python_scripts/src/image_processing/computational_models.py:191, in detect_faces(video, face_model, person_model, scale)
#     189 except IndexError: # if face_model detects no face
#     190     try: # tries  to detect a face with the person_model
# --> 191         x1, y1, x2, y2, confidence = compute_occluded_face_box(frame, person_model)
#     192         confidence = round(confidence, 3)
#     193         face_presence = 2 # occluded
#
# File ~/Desktop/temporal_context/python_scripts/src/image_processing/computational_models.py:131, in compute_occluded_face_box(frame, person_model)
#     130 def compute_occluded_face_box(frame, person_model):
# --> 131     results = person_model(frame, classes=[0], verbose=False)
#     132     if len(results[0].boxes) == 0:
#     133         raise IndexError("No detections found.")
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/ultralytics/engine/model.py:187, in Model.__call__(self, source, stream, **kwargs)
#     158 def __call__(
#     159     self,
#     160     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     161     stream: bool = False,
#     162     **kwargs: Any,
#     163 ) -> list:
#     164     """
#     165     Alias for the predict method, enabling the model instance to be callable for predictions.
#     166
#    (...)    185         ...     print(f"Detected {len(r)} objects in image")
#     186     """
# --> 187     return self.predict(source, stream, **kwargs)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/ultralytics/engine/model.py:557, in Model.predict(self, source, stream, predictor, **kwargs)
#     555 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     556     self.predictor.set_prompts(prompts)
# --> 557 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/ultralytics/engine/predictor.py:230, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     228     return self.stream_inference(source, model, *args, **kwargs)
#     229 else:
# --> 230     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/utils/_contextlib.py:38, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      35 try:
#      36     # Issuing `None` to a generator fires it up
#      37     with ctx_factory():
# ---> 38         response = gen.send(None)
#      40     while True:
#      41         try:
#      42             # Forward the response to our caller and get its next request
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/ultralytics/engine/predictor.py:337, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     335 # Inference
#     336 with profilers[1]:
# --> 337     preds = self.inference(im, *args, **kwargs)
#     338     if self.args.embed:
#     339         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/ultralytics/engine/predictor.py:185, in BasePredictor.inference(self, im, *args, **kwargs)
#     179 """Run inference on a given image using the specified model and arguments."""
#     180 visualize = (
#     181     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     182     if self.args.visualize and (not self.source_type.tensor)
#     183     else False
#     184 )
# --> 185 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/ultralytics/nn/autobackend.py:663, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     661 # PyTorch
#     662 if self.pt or self.nn_module:
# --> 663     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     665 # TorchScript
#     666 elif self.jit:
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/ultralytics/nn/tasks.py:139, in BaseModel.forward(self, x, *args, **kwargs)
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
#     138     return self.loss(x, *args, **kwargs)
# --> 139 return self.predict(x, *args, **kwargs)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/ultralytics/nn/tasks.py:157, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     155 if augment:
#     156     return self._predict_augment(x)
# --> 157 return self._predict_once(x, profile, visualize, embed)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/ultralytics/nn/tasks.py:180, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     178 if profile:
#     179     self._profile_one_layer(m, x, dt)
# --> 180 x = m(x)  # run
#     181 y.append(x if m.i in self.save else None)  # save output
#     182 if visualize:
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/ultralytics/nn/modules/head.py:122, in Detect.forward(self, x)
#     119     return self.forward_end2end(x)
#     121 for i in range(self.nl):
# --> 122     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#     123 if self.training:  # Training path
#     124     return x
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/ultralytics/nn/modules/conv.py:93, in Conv.forward_fuse(self, x)
#      83 def forward_fuse(self, x):
#      84     """
#      85     Apply convolution and activation without batch normalization.
#      86
#    (...)     91         (torch.Tensor): Output tensor.
#      92     """
# ---> 93     return self.act(self.conv(x))
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/modules/activation.py:434, in SiLU.forward(self, input)
#     433 def forward(self, input: Tensor) -> Tensor:
# --> 434     return F.silu(input, inplace=self.inplace)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/torch/nn/functional.py:2374, in silu(input, inplace)
#    2372     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2373 if inplace:
# -> 2374     return torch._C._nn.silu_(input)
#    2375 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:

# %%
from scipy.io import loadmat
coords = loadmat(f"{paths['livingstone_lab']}/tiziano/models/human_face_detection_{fn[:-4]}.mat")['coords']

# %%
# print and check
for i in range(v.shape[0]):
    plt.imshow(v[i, :, :, :])
    if coords[1, i] is not None:
        points = make_corners(*coords[2:, i])
        plt.plot(points[:, 0], points[:, 1], 'r-', linewidth=2)
    if coords[0, i] == 0:
        label = "no face"
    elif coords[0, i] == 1:
        label = f"face {coords[1, i]}"
    elif coords[0, i] == 2:
        label = f"occluded {coords[1, i]}"
    plt.text(1, 0.8, label, fontsize=12,
            bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.3"))
    plt.show()
    clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 15
#      12     label = f"occluded {coords[1, i]}"
#      13 plt.text(1, 0.8, label, fontsize=12,
#      14         bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.3"))
# ---> 15 plt.show()
#      16 clear_output(wait=True)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)    524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/IPython/core/display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     276     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#     281         continue
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/IPython/core/formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/IPython/core/formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/backend_bases.py:2164, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2161     # we do this instead of `self.figure.draw_without_rendering`
#    2162     # so that we can inject the orientation
#    2163     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2164         self.figure.draw(renderer)
#    2165 if bbox_inches:
#    2166     if bbox_inches == "tight":
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/image.py:649, in _ImageBase.draw(self, renderer, *args, **kwargs)
#     647         renderer.draw_image(gc, l, b, im, trans)
#     648 else:
# --> 649     im, l, b, trans = self.make_image(
#     650         renderer, renderer.get_image_magnification())
#     651     if im is not None:
#     652         renderer.draw_image(gc, l, b, im)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/image.py:939, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     936 transformed_bbox = TransformedBbox(bbox, trans)
#     937 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     938         else self.figure.bbox)
# --> 939 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     940                         magnification, unsampled=unsampled)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/image.py:560, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     558 if A.shape[2] == 3:
#     559     A = _rgb_to_rgba(A)
# --> 560 alpha = self._get_scalar_alpha()
#     561 output_alpha = _resample(  # resample alpha channel
#     562     self, A[..., 3], out_shape, t, alpha=alpha)
#     563 output = _resample(  # resample rgb channels
#     564     self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#
# File ~/Desktop/virtual_envs/temporal_context/lib/python3.12/site-packages/matplotlib/image.py:315, in _ImageBase._get_scalar_alpha(self)
#     311         raise TypeError('alpha must be a float, two-dimensional '
#     312                         'array, or None')
#     313     self._imcache = None
# --> 315 def _get_scalar_alpha(self):
#     316     """
#     317     Get a scalar alpha value to be applied to the artist as a whole.
#     318
#    (...)    323     individual alpha values.
#     324     """
#     325     return 1.0 if self._alpha is None or np.ndim(self._alpha) > 0 \
#     326         else self._alpha
#
# KeyboardInterrupt:

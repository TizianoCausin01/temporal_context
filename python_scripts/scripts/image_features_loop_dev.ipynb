# %%
import os, yaml, sys
import numpy as np
import torch
import h5py
import joblib
from torchvision import models
from scipy.spatial.distance import squareform
import matplotlib.pyplot as plt
from scipy.io import loadmat
from sklearn.decomposition import PCA
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision.models.feature_extraction import (
    create_feature_extractor,
    get_graph_node_names,
)

ENV = os.getenv("MY_ENV", "dev")
with open("../../config.yaml", "r") as f:
    config = yaml.safe_load(f)
paths = config[ENV]["paths"]
sys.path.append(paths["src_path"])
from general_utils.utils import create_RDM, get_device
from image_processing.utils import get_usual_transform, load_torchvision_model, map_anns_names, load_timm_model
from image_processing.computational_models import img_feats_extraction, map_image_order_from_ann_to_monkey
from general_utils.utils import print_wise, get_device, decode_matlab_strings, create_RDM, subsample_RDM
device = get_device()
# Out:
# 15:23:00 - device being used: mps

# %% [markdown]
# ## Feature extraction
# - 1. create dataset and transform
# - 2. loop through dataset
# - 3. create a list to keep the indices of presentation of the images (see presentation order and mapping)
# - 4. compute RDM and store it
# - 5. do PCA and store it
# - 6. project features
# - 7. map ANNs' presentation order onto neurons' presentation order (so that then we have everything ordered)
# - 8. compute RDM and store it
# - 9. store dimensionality reduced features and PCA object

# %% [markdown]
# Initialize variables

# %%
from dataclasses import dataclass

@dataclass
class Cfg:
    imsize: int = 384
    data_folder: str = 'fewer_occlusion'
    batch_size: int = 100
    n_components: int = 3
    model_name: str = 'vit_l_16'
    layer_name: str = 'blocks.18.mlp.fc2'
    monkey_name: str = 'paul' 
    date: str = '230204'


cfg = Cfg()

# %%
get_graph_node_names(model)
# Out:
# (['x',
#   'attn_mask',
#   'patch_embed.getattr',
#   'patch_embed.getitem',
#   'patch_embed.getitem_1',
#   'patch_embed.getitem_2',
#   'patch_embed.getitem_3',
#   'patch_embed.eq',
#   'patch_embed._assert',
#   'patch_embed.eq_1',
#   'patch_embed._assert_1',
#   'patch_embed.proj',
#   'patch_embed.flatten',
#   'patch_embed.transpose',
#   'patch_embed.norm',
#   'pos_embed',
#   'cls_token',
#   'getattr',
#   'getitem',
#   'expand',
#   'cat',
#   'add',
#   'pos_drop',
#   'patch_drop',
#   'norm_pre',
#   'blocks.0.norm1.blocks_0_norm1_weight',
#   'blocks.0.norm1.blocks_0_norm1_bias',
#   'blocks.0.norm1.layer_norm',
#   'blocks.0.attn.getattr',
#   'blocks.0.attn.getitem',
#   'blocks.0.attn.getitem_1',
#   'blocks.0.attn.getitem_2',
#   'blocks.0.attn.qkv',
#   'blocks.0.attn.reshape',
#   'blocks.0.attn.permute',
#   'blocks.0.attn.unbind',
#   'blocks.0.attn.getitem_3',
#   'blocks.0.attn.getitem_4',
#   'blocks.0.attn.getitem_5',
#   'blocks.0.attn.q_norm',
#   'blocks.0.attn.k_norm',
#   'blocks.0.attn.scaled_dot_product_attention',
#   'blocks.0.attn.transpose',
#   'blocks.0.attn.reshape_1',
#   'blocks.0.attn.norm',
#   'blocks.0.attn.proj',
#   'blocks.0.attn.proj_drop',
#   'blocks.0.ls1',
#   'blocks.0.drop_path1',
#   'blocks.0.add',
#   'blocks.0.norm2.blocks_0_norm2_weight',
#   'blocks.0.norm2.blocks_0_norm2_bias',
#   'blocks.0.norm2.layer_norm',
#   'blocks.0.mlp.fc1',
#   'blocks.0.mlp.act',
#   'blocks.0.mlp.drop1',
#   'blocks.0.mlp.norm',
#   'blocks.0.mlp.fc2',
#   'blocks.0.mlp.drop2',
#   'blocks.0.ls2',
#   'blocks.0.drop_path2',
#   'blocks.0.add_1',
#   'blocks.1.norm1.blocks_1_norm1_weight',
#   'blocks.1.norm1.blocks_1_norm1_bias',
#   'blocks.1.norm1.layer_norm',
#   'blocks.1.attn.getattr',
#   'blocks.1.attn.getitem',
#   'blocks.1.attn.getitem_1',
#   'blocks.1.attn.getitem_2',
#   'blocks.1.attn.qkv',
#   'blocks.1.attn.reshape',
#   'blocks.1.attn.permute',
#   'blocks.1.attn.unbind',
#   'blocks.1.attn.getitem_3',
#   'blocks.1.attn.getitem_4',
#   'blocks.1.attn.getitem_5',
#   'blocks.1.attn.q_norm',
#   'blocks.1.attn.k_norm',
#   'blocks.1.attn.scaled_dot_product_attention',
#   'blocks.1.attn.transpose',
#   'blocks.1.attn.reshape_1',
#   'blocks.1.attn.norm',
#   'blocks.1.attn.proj',
#   'blocks.1.attn.proj_drop',
#   'blocks.1.ls1',
#   'blocks.1.drop_path1',
#   'blocks.1.add',
#   'blocks.1.norm2.blocks_1_norm2_weight',
#   'blocks.1.norm2.blocks_1_norm2_bias',
#   'blocks.1.norm2.layer_norm',
#   'blocks.1.mlp.fc1',
#   'blocks.1.mlp.act',
#   'blocks.1.mlp.drop1',
#   'blocks.1.mlp.norm',
#   'blocks.1.mlp.fc2',
#   'blocks.1.mlp.drop2',
#   'blocks.1.ls2',
#   'blocks.1.drop_path2',
#   'blocks.1.add_1',
#   'blocks.2.norm1.blocks_2_norm1_weight',
#   'blocks.2.norm1.blocks_2_norm1_bias',
#   'blocks.2.norm1.layer_norm',
#   'blocks.2.attn.getattr',
#   'blocks.2.attn.getitem',
#   'blocks.2.attn.getitem_1',
#   'blocks.2.attn.getitem_2',
#   'blocks.2.attn.qkv',
#   'blocks.2.attn.reshape',
#   'blocks.2.attn.permute',
#   'blocks.2.attn.unbind',
#   'blocks.2.attn.getitem_3',
#   'blocks.2.attn.getitem_4',
#   'blocks.2.attn.getitem_5',
#   'blocks.2.attn.q_norm',
#   'blocks.2.attn.k_norm',
#   'blocks.2.attn.scaled_dot_product_attention',
#   'blocks.2.attn.transpose',
#   'blocks.2.attn.reshape_1',
#   'blocks.2.attn.norm',
#   'blocks.2.attn.proj',
#   'blocks.2.attn.proj_drop',
#   'blocks.2.ls1',
#   'blocks.2.drop_path1',
#   'blocks.2.add',
#   'blocks.2.norm2.blocks_2_norm2_weight',
#   'blocks.2.norm2.blocks_2_norm2_bias',
#   'blocks.2.norm2.layer_norm',
#   'blocks.2.mlp.fc1',
#   'blocks.2.mlp.act',
#   'blocks.2.mlp.drop1',
#   'blocks.2.mlp.norm',
#   'blocks.2.mlp.fc2',
#   'blocks.2.mlp.drop2',
#   'blocks.2.ls2',
#   'blocks.2.drop_path2',
#   'blocks.2.add_1',
#   'blocks.3.norm1.blocks_3_norm1_weight',
#   'blocks.3.norm1.blocks_3_norm1_bias',
#   'blocks.3.norm1.layer_norm',
#   'blocks.3.attn.getattr',
#   'blocks.3.attn.getitem',
#   'blocks.3.attn.getitem_1',
#   'blocks.3.attn.getitem_2',
#   'blocks.3.attn.qkv',
#   'blocks.3.attn.reshape',
#   'blocks.3.attn.permute',
#   'blocks.3.attn.unbind',
#   'blocks.3.attn.getitem_3',
#   'blocks.3.attn.getitem_4',
#   'blocks.3.attn.getitem_5',
#   'blocks.3.attn.q_norm',
#   'blocks.3.attn.k_norm',
#   'blocks.3.attn.scaled_dot_product_attention',
#   'blocks.3.attn.transpose',
#   'blocks.3.attn.reshape_1',
#   'blocks.3.attn.norm',
#   'blocks.3.attn.proj',
#   'blocks.3.attn.proj_drop',
#   'blocks.3.ls1',
#   'blocks.3.drop_path1',
#   'blocks.3.add',
#   'blocks.3.norm2.blocks_3_norm2_weight',
#   'blocks.3.norm2.blocks_3_norm2_bias',
#   'blocks.3.norm2.layer_norm',
#   'blocks.3.mlp.fc1',
#   'blocks.3.mlp.act',
#   'blocks.3.mlp.drop1',
#   'blocks.3.mlp.norm',
#   'blocks.3.mlp.fc2',
#   'blocks.3.mlp.drop2',
#   'blocks.3.ls2',
#   'blocks.3.drop_path2',
#   'blocks.3.add_1',
#   'blocks.4.norm1.blocks_4_norm1_weight',
#   'blocks.4.norm1.blocks_4_norm1_bias',
#   'blocks.4.norm1.layer_norm',
#   'blocks.4.attn.getattr',
#   'blocks.4.attn.getitem',
#   'blocks.4.attn.getitem_1',
#   'blocks.4.attn.getitem_2',
#   'blocks.4.attn.qkv',
#   'blocks.4.attn.reshape',
#   'blocks.4.attn.permute',
#   'blocks.4.attn.unbind',
#   'blocks.4.attn.getitem_3',
#   'blocks.4.attn.getitem_4',
#   'blocks.4.attn.getitem_5',
#   'blocks.4.attn.q_norm',
#   'blocks.4.attn.k_norm',
#   'blocks.4.attn.scaled_dot_product_attention',
#   'blocks.4.attn.transpose',
#   'blocks.4.attn.reshape_1',
#   'blocks.4.attn.norm',
#   'blocks.4.attn.proj',
#   'blocks.4.attn.proj_drop',
#   'blocks.4.ls1',
#   'blocks.4.drop_path1',
#   'blocks.4.add',
#   'blocks.4.norm2.blocks_4_norm2_weight',
#   'blocks.4.norm2.blocks_4_norm2_bias',
#   'blocks.4.norm2.layer_norm',
#   'blocks.4.mlp.fc1',
#   'blocks.4.mlp.act',
#   'blocks.4.mlp.drop1',
#   'blocks.4.mlp.norm',
#   'blocks.4.mlp.fc2',
#   'blocks.4.mlp.drop2',
#   'blocks.4.ls2',
#   'blocks.4.drop_path2',
#   'blocks.4.add_1',
#   'blocks.5.norm1.blocks_5_norm1_weight',
#   'blocks.5.norm1.blocks_5_norm1_bias',
#   'blocks.5.norm1.layer_norm',
#   'blocks.5.attn.getattr',
#   'blocks.5.attn.getitem',
#   'blocks.5.attn.getitem_1',
#   'blocks.5.attn.getitem_2',
#   'blocks.5.attn.qkv',
#   'blocks.5.attn.reshape',
#   'blocks.5.attn.permute',
#   'blocks.5.attn.unbind',
#   'blocks.5.attn.getitem_3',
#   'blocks.5.attn.getitem_4',
#   'blocks.5.attn.getitem_5',
#   'blocks.5.attn.q_norm',
#   'blocks.5.attn.k_norm',
#   'blocks.5.attn.scaled_dot_product_attention',
#   'blocks.5.attn.transpose',
#   'blocks.5.attn.reshape_1',
#   'blocks.5.attn.norm',
#   'blocks.5.attn.proj',
#   'blocks.5.attn.proj_drop',
#   'blocks.5.ls1',
#   'blocks.5.drop_path1',
#   'blocks.5.add',
#   'blocks.5.norm2.blocks_5_norm2_weight',
#   'blocks.5.norm2.blocks_5_norm2_bias',
#   'blocks.5.norm2.layer_norm',
#   'blocks.5.mlp.fc1',
#   'blocks.5.mlp.act',
#   'blocks.5.mlp.drop1',
#   'blocks.5.mlp.norm',
#   'blocks.5.mlp.fc2',
#   'blocks.5.mlp.drop2',
#   'blocks.5.ls2',
#   'blocks.5.drop_path2',
#   'blocks.5.add_1',
#   'blocks.6.norm1.blocks_6_norm1_weight',
#   'blocks.6.norm1.blocks_6_norm1_bias',
#   'blocks.6.norm1.layer_norm',
#   'blocks.6.attn.getattr',
#   'blocks.6.attn.getitem',
#   'blocks.6.attn.getitem_1',
#   'blocks.6.attn.getitem_2',
#   'blocks.6.attn.qkv',
#   'blocks.6.attn.reshape',
#   'blocks.6.attn.permute',
#   'blocks.6.attn.unbind',
#   'blocks.6.attn.getitem_3',
#   'blocks.6.attn.getitem_4',
#   'blocks.6.attn.getitem_5',
#   'blocks.6.attn.q_norm',
#   'blocks.6.attn.k_norm',
#   'blocks.6.attn.scaled_dot_product_attention',
#   'blocks.6.attn.transpose',
#   'blocks.6.attn.reshape_1',
#   'blocks.6.attn.norm',
#   'blocks.6.attn.proj',
#   'blocks.6.attn.proj_drop',
#   'blocks.6.ls1',
#   'blocks.6.drop_path1',
#   'blocks.6.add',
#   'blocks.6.norm2.blocks_6_norm2_weight',
#   'blocks.6.norm2.blocks_6_norm2_bias',
#   'blocks.6.norm2.layer_norm',
#   'blocks.6.mlp.fc1',
#   'blocks.6.mlp.act',
#   'blocks.6.mlp.drop1',
#   'blocks.6.mlp.norm',
#   'blocks.6.mlp.fc2',
#   'blocks.6.mlp.drop2',
#   'blocks.6.ls2',
#   'blocks.6.drop_path2',
#   'blocks.6.add_1',
#   'blocks.7.norm1.blocks_7_norm1_weight',
#   'blocks.7.norm1.blocks_7_norm1_bias',
#   'blocks.7.norm1.layer_norm',
#   'blocks.7.attn.getattr',
#   'blocks.7.attn.getitem',
#   'blocks.7.attn.getitem_1',
#   'blocks.7.attn.getitem_2',
#   'blocks.7.attn.qkv',
#   'blocks.7.attn.reshape',
#   'blocks.7.attn.permute',
#   'blocks.7.attn.unbind',
#   'blocks.7.attn.getitem_3',
#   'blocks.7.attn.getitem_4',
#   'blocks.7.attn.getitem_5',
#   'blocks.7.attn.q_norm',
#   'blocks.7.attn.k_norm',
#   'blocks.7.attn.scaled_dot_product_attention',
#   'blocks.7.attn.transpose',
#   'blocks.7.attn.reshape_1',
#   'blocks.7.attn.norm',
#   'blocks.7.attn.proj',
#   'blocks.7.attn.proj_drop',
#   'blocks.7.ls1',
#   'blocks.7.drop_path1',
#   'blocks.7.add',
#   'blocks.7.norm2.blocks_7_norm2_weight',
#   'blocks.7.norm2.blocks_7_norm2_bias',
#   'blocks.7.norm2.layer_norm',
#   'blocks.7.mlp.fc1',
#   'blocks.7.mlp.act',
#   'blocks.7.mlp.drop1',
#   'blocks.7.mlp.norm',
#   'blocks.7.mlp.fc2',
#   'blocks.7.mlp.drop2',
#   'blocks.7.ls2',
#   'blocks.7.drop_path2',
#   'blocks.7.add_1',
#   'blocks.8.norm1.blocks_8_norm1_weight',
#   'blocks.8.norm1.blocks_8_norm1_bias',
#   'blocks.8.norm1.layer_norm',
#   'blocks.8.attn.getattr',
#   'blocks.8.attn.getitem',
#   'blocks.8.attn.getitem_1',
#   'blocks.8.attn.getitem_2',
#   'blocks.8.attn.qkv',
#   'blocks.8.attn.reshape',
#   'blocks.8.attn.permute',
#   'blocks.8.attn.unbind',
#   'blocks.8.attn.getitem_3',
#   'blocks.8.attn.getitem_4',
#   'blocks.8.attn.getitem_5',
#   'blocks.8.attn.q_norm',
#   'blocks.8.attn.k_norm',
#   'blocks.8.attn.scaled_dot_product_attention',
#   'blocks.8.attn.transpose',
#   'blocks.8.attn.reshape_1',
#   'blocks.8.attn.norm',
#   'blocks.8.attn.proj',
#   'blocks.8.attn.proj_drop',
#   'blocks.8.ls1',
#   'blocks.8.drop_path1',
#   'blocks.8.add',
#   'blocks.8.norm2.blocks_8_norm2_weight',
#   'blocks.8.norm2.blocks_8_norm2_bias',
#   'blocks.8.norm2.layer_norm',
#   'blocks.8.mlp.fc1',
#   'blocks.8.mlp.act',
#   'blocks.8.mlp.drop1',
#   'blocks.8.mlp.norm',
#   'blocks.8.mlp.fc2',
#   'blocks.8.mlp.drop2',
#   'blocks.8.ls2',
#   'blocks.8.drop_path2',
#   'blocks.8.add_1',
#   'blocks.9.norm1.blocks_9_norm1_weight',
#   'blocks.9.norm1.blocks_9_norm1_bias',
#   'blocks.9.norm1.layer_norm',
#   'blocks.9.attn.getattr',
#   'blocks.9.attn.getitem',
#   'blocks.9.attn.getitem_1',
#   'blocks.9.attn.getitem_2',
#   'blocks.9.attn.qkv',
#   'blocks.9.attn.reshape',
#   'blocks.9.attn.permute',
#   'blocks.9.attn.unbind',
#   'blocks.9.attn.getitem_3',
#   'blocks.9.attn.getitem_4',
#   'blocks.9.attn.getitem_5',
#   'blocks.9.attn.q_norm',
#   'blocks.9.attn.k_norm',
#   'blocks.9.attn.scaled_dot_product_attention',
#   'blocks.9.attn.transpose',
#   'blocks.9.attn.reshape_1',
#   'blocks.9.attn.norm',
#   'blocks.9.attn.proj',
#   'blocks.9.attn.proj_drop',
#   'blocks.9.ls1',
#   'blocks.9.drop_path1',
#   'blocks.9.add',
#   'blocks.9.norm2.blocks_9_norm2_weight',
#   'blocks.9.norm2.blocks_9_norm2_bias',
#   'blocks.9.norm2.layer_norm',
#   'blocks.9.mlp.fc1',
#   'blocks.9.mlp.act',
#   'blocks.9.mlp.drop1',
#   'blocks.9.mlp.norm',
#   'blocks.9.mlp.fc2',
#   'blocks.9.mlp.drop2',
#   'blocks.9.ls2',
#   'blocks.9.drop_path2',
#   'blocks.9.add_1',
#   'blocks.10.norm1.blocks_10_norm1_weight',
#   'blocks.10.norm1.blocks_10_norm1_bias',
#   'blocks.10.norm1.layer_norm',
#   'blocks.10.attn.getattr',
#   'blocks.10.attn.getitem',
#   'blocks.10.attn.getitem_1',
#   'blocks.10.attn.getitem_2',
#   'blocks.10.attn.qkv',
#   'blocks.10.attn.reshape',
#   'blocks.10.attn.permute',
#   'blocks.10.attn.unbind',
#   'blocks.10.attn.getitem_3',
#   'blocks.10.attn.getitem_4',
#   'blocks.10.attn.getitem_5',
#   'blocks.10.attn.q_norm',
#   'blocks.10.attn.k_norm',
#   'blocks.10.attn.scaled_dot_product_attention',
#   'blocks.10.attn.transpose',
#   'blocks.10.attn.reshape_1',
#   'blocks.10.attn.norm',
#   'blocks.10.attn.proj',
#   'blocks.10.attn.proj_drop',
#   'blocks.10.ls1',
#   'blocks.10.drop_path1',
#   'blocks.10.add',
#   'blocks.10.norm2.blocks_10_norm2_weight',
#   'blocks.10.norm2.blocks_10_norm2_bias',
#   'blocks.10.norm2.layer_norm',
#   'blocks.10.mlp.fc1',
#   'blocks.10.mlp.act',
#   'blocks.10.mlp.drop1',
#   'blocks.10.mlp.norm',
#   'blocks.10.mlp.fc2',
#   'blocks.10.mlp.drop2',
#   'blocks.10.ls2',
#   'blocks.10.drop_path2',
#   'blocks.10.add_1',
#   'blocks.11.norm1.blocks_11_norm1_weight',
#   'blocks.11.norm1.blocks_11_norm1_bias',
#   'blocks.11.norm1.layer_norm',
#   'blocks.11.attn.getattr',
#   'blocks.11.attn.getitem',
#   'blocks.11.attn.getitem_1',
#   'blocks.11.attn.getitem_2',
#   'blocks.11.attn.qkv',
#   'blocks.11.attn.reshape',
#   'blocks.11.attn.permute',
#   'blocks.11.attn.unbind',
#   'blocks.11.attn.getitem_3',
#   'blocks.11.attn.getitem_4',
#   'blocks.11.attn.getitem_5',
#   'blocks.11.attn.q_norm',
#   'blocks.11.attn.k_norm',
#   'blocks.11.attn.scaled_dot_product_attention',
#   'blocks.11.attn.transpose',
#   'blocks.11.attn.reshape_1',
#   'blocks.11.attn.norm',
#   'blocks.11.attn.proj',
#   'blocks.11.attn.proj_drop',
#   'blocks.11.ls1',
#   'blocks.11.drop_path1',
#   'blocks.11.add',
#   'blocks.11.norm2.blocks_11_norm2_weight',
#   'blocks.11.norm2.blocks_11_norm2_bias',
#   'blocks.11.norm2.layer_norm',
#   'blocks.11.mlp.fc1',
#   'blocks.11.mlp.act',
#   'blocks.11.mlp.drop1',
#   'blocks.11.mlp.norm',
#   'blocks.11.mlp.fc2',
#   'blocks.11.mlp.drop2',
#   'blocks.11.ls2',
#   'blocks.11.drop_path2',
#   'blocks.11.add_1',
#   'blocks.12.norm1.blocks_12_norm1_weight',
#   'blocks.12.norm1.blocks_12_norm1_bias',
#   'blocks.12.norm1.layer_norm',
#   'blocks.12.attn.getattr',
#   'blocks.12.attn.getitem',
#   'blocks.12.attn.getitem_1',
#   'blocks.12.attn.getitem_2',
#   'blocks.12.attn.qkv',
#   'blocks.12.attn.reshape',
#   'blocks.12.attn.permute',
#   'blocks.12.attn.unbind',
#   'blocks.12.attn.getitem_3',
#   'blocks.12.attn.getitem_4',
#   'blocks.12.attn.getitem_5',
#   'blocks.12.attn.q_norm',
#   'blocks.12.attn.k_norm',
#   'blocks.12.attn.scaled_dot_product_attention',
#   'blocks.12.attn.transpose',
#   'blocks.12.attn.reshape_1',
#   'blocks.12.attn.norm',
#   'blocks.12.attn.proj',
#   'blocks.12.attn.proj_drop',
#   'blocks.12.ls1',
#   'blocks.12.drop_path1',
#   'blocks.12.add',
#   'blocks.12.norm2.blocks_12_norm2_weight',
#   'blocks.12.norm2.blocks_12_norm2_bias',
#   'blocks.12.norm2.layer_norm',
#   'blocks.12.mlp.fc1',
#   'blocks.12.mlp.act',
#   'blocks.12.mlp.drop1',
#   'blocks.12.mlp.norm',
#   'blocks.12.mlp.fc2',
#   'blocks.12.mlp.drop2',
#   'blocks.12.ls2',
#   'blocks.12.drop_path2',
#   'blocks.12.add_1',
#   'blocks.13.norm1.blocks_13_norm1_weight',
#   'blocks.13.norm1.blocks_13_norm1_bias',
#   'blocks.13.norm1.layer_norm',
#   'blocks.13.attn.getattr',
#   'blocks.13.attn.getitem',
#   'blocks.13.attn.getitem_1',
#   'blocks.13.attn.getitem_2',
#   'blocks.13.attn.qkv',
#   'blocks.13.attn.reshape',
#   'blocks.13.attn.permute',
#   'blocks.13.attn.unbind',
#   'blocks.13.attn.getitem_3',
#   'blocks.13.attn.getitem_4',
#   'blocks.13.attn.getitem_5',
#   'blocks.13.attn.q_norm',
#   'blocks.13.attn.k_norm',
#   'blocks.13.attn.scaled_dot_product_attention',
#   'blocks.13.attn.transpose',
#   'blocks.13.attn.reshape_1',
#   'blocks.13.attn.norm',
#   'blocks.13.attn.proj',
#   'blocks.13.attn.proj_drop',
#   'blocks.13.ls1',
#   'blocks.13.drop_path1',
#   'blocks.13.add',
#   'blocks.13.norm2.blocks_13_norm2_weight',
#   'blocks.13.norm2.blocks_13_norm2_bias',
#   'blocks.13.norm2.layer_norm',
#   'blocks.13.mlp.fc1',
#   'blocks.13.mlp.act',
#   'blocks.13.mlp.drop1',
#   'blocks.13.mlp.norm',
#   'blocks.13.mlp.fc2',
#   'blocks.13.mlp.drop2',
#   'blocks.13.ls2',
#   'blocks.13.drop_path2',
#   'blocks.13.add_1',
#   'blocks.14.norm1.blocks_14_norm1_weight',
#   'blocks.14.norm1.blocks_14_norm1_bias',
#   'blocks.14.norm1.layer_norm',
#   'blocks.14.attn.getattr',
#   'blocks.14.attn.getitem',
#   'blocks.14.attn.getitem_1',
#   'blocks.14.attn.getitem_2',
#   'blocks.14.attn.qkv',
#   'blocks.14.attn.reshape',
#   'blocks.14.attn.permute',
#   'blocks.14.attn.unbind',
#   'blocks.14.attn.getitem_3',
#   'blocks.14.attn.getitem_4',
#   'blocks.14.attn.getitem_5',
#   'blocks.14.attn.q_norm',
#   'blocks.14.attn.k_norm',
#   'blocks.14.attn.scaled_dot_product_attention',
#   'blocks.14.attn.transpose',
#   'blocks.14.attn.reshape_1',
#   'blocks.14.attn.norm',
#   'blocks.14.attn.proj',
#   'blocks.14.attn.proj_drop',
#   'blocks.14.ls1',
#   'blocks.14.drop_path1',
#   'blocks.14.add',
#   'blocks.14.norm2.blocks_14_norm2_weight',
#   'blocks.14.norm2.blocks_14_norm2_bias',
#   'blocks.14.norm2.layer_norm',
#   'blocks.14.mlp.fc1',
#   'blocks.14.mlp.act',
#   'blocks.14.mlp.drop1',
#   'blocks.14.mlp.norm',
#   'blocks.14.mlp.fc2',
#   'blocks.14.mlp.drop2',
#   'blocks.14.ls2',
#   'blocks.14.drop_path2',
#   'blocks.14.add_1',
#   'blocks.15.norm1.blocks_15_norm1_weight',
#   'blocks.15.norm1.blocks_15_norm1_bias',
#   'blocks.15.norm1.layer_norm',
#   'blocks.15.attn.getattr',
#   'blocks.15.attn.getitem',
#   'blocks.15.attn.getitem_1',
#   'blocks.15.attn.getitem_2',
#   'blocks.15.attn.qkv',
#   'blocks.15.attn.reshape',
#   'blocks.15.attn.permute',
#   'blocks.15.attn.unbind',
#   'blocks.15.attn.getitem_3',
#   'blocks.15.attn.getitem_4',
#   'blocks.15.attn.getitem_5',
#   'blocks.15.attn.q_norm',
#   'blocks.15.attn.k_norm',
#   'blocks.15.attn.scaled_dot_product_attention',
#   'blocks.15.attn.transpose',
#   'blocks.15.attn.reshape_1',
#   'blocks.15.attn.norm',
#   'blocks.15.attn.proj',
#   'blocks.15.attn.proj_drop',
#   'blocks.15.ls1',
#   'blocks.15.drop_path1',
#   'blocks.15.add',
#   'blocks.15.norm2.blocks_15_norm2_weight',
#   'blocks.15.norm2.blocks_15_norm2_bias',
#   'blocks.15.norm2.layer_norm',
#   'blocks.15.mlp.fc1',
#   'blocks.15.mlp.act',
#   'blocks.15.mlp.drop1',
#   'blocks.15.mlp.norm',
#   'blocks.15.mlp.fc2',
#   'blocks.15.mlp.drop2',
#   'blocks.15.ls2',
#   'blocks.15.drop_path2',
#   'blocks.15.add_1',
#   'blocks.16.norm1.blocks_16_norm1_weight',
#   'blocks.16.norm1.blocks_16_norm1_bias',
#   'blocks.16.norm1.layer_norm',
#   'blocks.16.attn.getattr',
#   'blocks.16.attn.getitem',
#   'blocks.16.attn.getitem_1',
#   'blocks.16.attn.getitem_2',
#   'blocks.16.attn.qkv',
#   'blocks.16.attn.reshape',
#   'blocks.16.attn.permute',
#   'blocks.16.attn.unbind',
#   'blocks.16.attn.getitem_3',
#   'blocks.16.attn.getitem_4',
#   'blocks.16.attn.getitem_5',
#   'blocks.16.attn.q_norm',
#   'blocks.16.attn.k_norm',
#   'blocks.16.attn.scaled_dot_product_attention',
#   'blocks.16.attn.transpose',
#   'blocks.16.attn.reshape_1',
#   'blocks.16.attn.norm',
#   'blocks.16.attn.proj',
#   'blocks.16.attn.proj_drop',
#   'blocks.16.ls1',
#   'blocks.16.drop_path1',
#   'blocks.16.add',
#   'blocks.16.norm2.blocks_16_norm2_weight',
#   'blocks.16.norm2.blocks_16_norm2_bias',
#   'blocks.16.norm2.layer_norm',
#   'blocks.16.mlp.fc1',
#   'blocks.16.mlp.act',
#   'blocks.16.mlp.drop1',
#   'blocks.16.mlp.norm',
#   'blocks.16.mlp.fc2',
#   'blocks.16.mlp.drop2',
#   'blocks.16.ls2',
#   'blocks.16.drop_path2',
#   'blocks.16.add_1',
#   'blocks.17.norm1.blocks_17_norm1_weight',
#   'blocks.17.norm1.blocks_17_norm1_bias',
#   'blocks.17.norm1.layer_norm',
#   'blocks.17.attn.getattr',
#   'blocks.17.attn.getitem',
#   'blocks.17.attn.getitem_1',
#   'blocks.17.attn.getitem_2',
#   'blocks.17.attn.qkv',
#   'blocks.17.attn.reshape',
#   'blocks.17.attn.permute',
#   'blocks.17.attn.unbind',
#   'blocks.17.attn.getitem_3',
#   'blocks.17.attn.getitem_4',
#   'blocks.17.attn.getitem_5',
#   'blocks.17.attn.q_norm',
#   'blocks.17.attn.k_norm',
#   'blocks.17.attn.scaled_dot_product_attention',
#   'blocks.17.attn.transpose',
#   'blocks.17.attn.reshape_1',
#   'blocks.17.attn.norm',
#   'blocks.17.attn.proj',
#   'blocks.17.attn.proj_drop',
#   'blocks.17.ls1',
#   'blocks.17.drop_path1',
#   'blocks.17.add',
#   'blocks.17.norm2.blocks_17_norm2_weight',
#   'blocks.17.norm2.blocks_17_norm2_bias',
#   'blocks.17.norm2.layer_norm',
#   'blocks.17.mlp.fc1',
#   'blocks.17.mlp.act',
#   'blocks.17.mlp.drop1',
#   'blocks.17.mlp.norm',
#   'blocks.17.mlp.fc2',
#   'blocks.17.mlp.drop2',
#   'blocks.17.ls2',
#   'blocks.17.drop_path2',
#   'blocks.17.add_1',
#   'blocks.18.norm1.blocks_18_norm1_weight',
#   'blocks.18.norm1.blocks_18_norm1_bias',
#   'blocks.18.norm1.layer_norm',
#   'blocks.18.attn.getattr',
#   'blocks.18.attn.getitem',
#   'blocks.18.attn.getitem_1',
#   'blocks.18.attn.getitem_2',
#   'blocks.18.attn.qkv',
#   'blocks.18.attn.reshape',
#   'blocks.18.attn.permute',
#   'blocks.18.attn.unbind',
#   'blocks.18.attn.getitem_3',
#   'blocks.18.attn.getitem_4',
#   'blocks.18.attn.getitem_5',
#   'blocks.18.attn.q_norm',
#   'blocks.18.attn.k_norm',
#   'blocks.18.attn.scaled_dot_product_attention',
#   'blocks.18.attn.transpose',
#   'blocks.18.attn.reshape_1',
#   'blocks.18.attn.norm',
#   'blocks.18.attn.proj',
#   'blocks.18.attn.proj_drop',
#   'blocks.18.ls1',
#   'blocks.18.drop_path1',
#   'blocks.18.add',
#   'blocks.18.norm2.blocks_18_norm2_weight',
#   'blocks.18.norm2.blocks_18_norm2_bias',
#   'blocks.18.norm2.layer_norm',
#   'blocks.18.mlp.fc1',
#   'blocks.18.mlp.act',
#   'blocks.18.mlp.drop1',
#   'blocks.18.mlp.norm',
#   'blocks.18.mlp.fc2',
#   'blocks.18.mlp.drop2',
#   'blocks.18.ls2',
#   'blocks.18.drop_path2',
#   'blocks.18.add_1',
#   'blocks.19.norm1.blocks_19_norm1_weight',
#   'blocks.19.norm1.blocks_19_norm1_bias',
#   'blocks.19.norm1.layer_norm',
#   'blocks.19.attn.getattr',
#   'blocks.19.attn.getitem',
#   'blocks.19.attn.getitem_1',
#   'blocks.19.attn.getitem_2',
#   'blocks.19.attn.qkv',
#   'blocks.19.attn.reshape',
#   'blocks.19.attn.permute',
#   'blocks.19.attn.unbind',
#   'blocks.19.attn.getitem_3',
#   'blocks.19.attn.getitem_4',
#   'blocks.19.attn.getitem_5',
#   'blocks.19.attn.q_norm',
#   'blocks.19.attn.k_norm',
#   'blocks.19.attn.scaled_dot_product_attention',
#   'blocks.19.attn.transpose',
#   'blocks.19.attn.reshape_1',
#   'blocks.19.attn.norm',
#   'blocks.19.attn.proj',
#   'blocks.19.attn.proj_drop',
#   'blocks.19.ls1',
#   'blocks.19.drop_path1',
#   'blocks.19.add',
#   'blocks.19.norm2.blocks_19_norm2_weight',
#   'blocks.19.norm2.blocks_19_norm2_bias',
#   'blocks.19.norm2.layer_norm',
#   'blocks.19.mlp.fc1',
#   'blocks.19.mlp.act',
#   'blocks.19.mlp.drop1',
#   'blocks.19.mlp.norm',
#   'blocks.19.mlp.fc2',
#   'blocks.19.mlp.drop2',
#   'blocks.19.ls2',
#   'blocks.19.drop_path2',
#   'blocks.19.add_1',
#   'blocks.20.norm1.blocks_20_norm1_weight',
#   'blocks.20.norm1.blocks_20_norm1_bias',
#   'blocks.20.norm1.layer_norm',
#   'blocks.20.attn.getattr',
#   'blocks.20.attn.getitem',
#   'blocks.20.attn.getitem_1',
#   'blocks.20.attn.getitem_2',
#   'blocks.20.attn.qkv',
#   'blocks.20.attn.reshape',
#   'blocks.20.attn.permute',
#   'blocks.20.attn.unbind',
#   'blocks.20.attn.getitem_3',
#   'blocks.20.attn.getitem_4',
#   'blocks.20.attn.getitem_5',
#   'blocks.20.attn.q_norm',
#   'blocks.20.attn.k_norm',
#   'blocks.20.attn.scaled_dot_product_attention',
#   'blocks.20.attn.transpose',
#   'blocks.20.attn.reshape_1',
#   'blocks.20.attn.norm',
#   'blocks.20.attn.proj',
#   'blocks.20.attn.proj_drop',
#   'blocks.20.ls1',
#   'blocks.20.drop_path1',
#   'blocks.20.add',
#   'blocks.20.norm2.blocks_20_norm2_weight',
#   'blocks.20.norm2.blocks_20_norm2_bias',
#   'blocks.20.norm2.layer_norm',
#   'blocks.20.mlp.fc1',
#   'blocks.20.mlp.act',
#   'blocks.20.mlp.drop1',
#   'blocks.20.mlp.norm',
#   'blocks.20.mlp.fc2',
#   'blocks.20.mlp.drop2',
#   'blocks.20.ls2',
#   'blocks.20.drop_path2',
#   'blocks.20.add_1',
#   'blocks.21.norm1.blocks_21_norm1_weight',
#   'blocks.21.norm1.blocks_21_norm1_bias',
#   'blocks.21.norm1.layer_norm',
#   'blocks.21.attn.getattr',
#   'blocks.21.attn.getitem',
#   'blocks.21.attn.getitem_1',
#   'blocks.21.attn.getitem_2',
#   'blocks.21.attn.qkv',
#   'blocks.21.attn.reshape',
#   'blocks.21.attn.permute',
#   'blocks.21.attn.unbind',
#   'blocks.21.attn.getitem_3',
#   'blocks.21.attn.getitem_4',
#   'blocks.21.attn.getitem_5',
#   'blocks.21.attn.q_norm',
#   'blocks.21.attn.k_norm',
#   'blocks.21.attn.scaled_dot_product_attention',
#   'blocks.21.attn.transpose',
#   'blocks.21.attn.reshape_1',
#   'blocks.21.attn.norm',
#   'blocks.21.attn.proj',
#   'blocks.21.attn.proj_drop',
#   'blocks.21.ls1',
#   'blocks.21.drop_path1',
#   'blocks.21.add',
#   'blocks.21.norm2.blocks_21_norm2_weight',
#   'blocks.21.norm2.blocks_21_norm2_bias',
#   'blocks.21.norm2.layer_norm',
#   'blocks.21.mlp.fc1',
#   'blocks.21.mlp.act',
#   'blocks.21.mlp.drop1',
#   'blocks.21.mlp.norm',
#   'blocks.21.mlp.fc2',
#   'blocks.21.mlp.drop2',
#   'blocks.21.ls2',
#   'blocks.21.drop_path2',
#   'blocks.21.add_1',
#   'blocks.22.norm1.blocks_22_norm1_weight',
#   'blocks.22.norm1.blocks_22_norm1_bias',
#   'blocks.22.norm1.layer_norm',
#   'blocks.22.attn.getattr',
#   'blocks.22.attn.getitem',
#   'blocks.22.attn.getitem_1',
#   'blocks.22.attn.getitem_2',
#   'blocks.22.attn.qkv',
#   'blocks.22.attn.reshape',
#   'blocks.22.attn.permute',
#   'blocks.22.attn.unbind',
#   'blocks.22.attn.getitem_3',
#   'blocks.22.attn.getitem_4',
#   'blocks.22.attn.getitem_5',
#   'blocks.22.attn.q_norm',
#   'blocks.22.attn.k_norm',
#   'blocks.22.attn.scaled_dot_product_attention',
#   'blocks.22.attn.transpose',
#   'blocks.22.attn.reshape_1',
#   'blocks.22.attn.norm',
#   'blocks.22.attn.proj',
#   'blocks.22.attn.proj_drop',
#   'blocks.22.ls1',
#   'blocks.22.drop_path1',
#   'blocks.22.add',
#   'blocks.22.norm2.blocks_22_norm2_weight',
#   'blocks.22.norm2.blocks_22_norm2_bias',
#   'blocks.22.norm2.layer_norm',
#   'blocks.22.mlp.fc1',
#   'blocks.22.mlp.act',
#   'blocks.22.mlp.drop1',
#   'blocks.22.mlp.norm',
#   'blocks.22.mlp.fc2',
#   'blocks.22.mlp.drop2',
#   'blocks.22.ls2',
#   'blocks.22.drop_path2',
#   'blocks.22.add_1',
#   'blocks.23.norm1.blocks_23_norm1_weight',
#   'blocks.23.norm1.blocks_23_norm1_bias',
#   'blocks.23.norm1.layer_norm',
#   'blocks.23.attn.getattr',
#   'blocks.23.attn.getitem',
#   'blocks.23.attn.getitem_1',
#   'blocks.23.attn.getitem_2',
#   'blocks.23.attn.qkv',
#   'blocks.23.attn.reshape',
#   'blocks.23.attn.permute',
#   'blocks.23.attn.unbind',
#   'blocks.23.attn.getitem_3',
#   'blocks.23.attn.getitem_4',
#   'blocks.23.attn.getitem_5',
#   'blocks.23.attn.q_norm',
#   'blocks.23.attn.k_norm',
#   'blocks.23.attn.scaled_dot_product_attention',
#   'blocks.23.attn.transpose',
#   'blocks.23.attn.reshape_1',
#   'blocks.23.attn.norm',
#   'blocks.23.attn.proj',
#   'blocks.23.attn.proj_drop',
#   'blocks.23.ls1',
#   'blocks.23.drop_path1',
#   'blocks.23.add',
#   'blocks.23.norm2.blocks_23_norm2_weight',
#   'blocks.23.norm2.blocks_23_norm2_bias',
#   'blocks.23.norm2.layer_norm',
#   'blocks.23.mlp.fc1',
#   'blocks.23.mlp.act',
#   'blocks.23.mlp.drop1',
#   'blocks.23.mlp.norm',
#   'blocks.23.mlp.fc2',
#   'blocks.23.mlp.drop2',
#   'blocks.23.ls2',
#   'blocks.23.drop_path2',
#   'blocks.23.add_1',
#   'norm.norm_weight',
#   'norm.norm_bias',
#   'norm.layer_norm',
#   'getitem_1',
#   'fc_norm',
#   'head_drop',
#   'head'],
#  ['x',
#   'attn_mask',
#   'patch_embed.getattr',
#   'patch_embed.getitem',
#   'patch_embed.getitem_1',
#   'patch_embed.getitem_2',
#   'patch_embed.getitem_3',
#   'patch_embed.eq',
#   'patch_embed._assert',
#   'patch_embed.eq_1',
#   'patch_embed._assert_1',
#   'patch_embed.proj',
#   'patch_embed.flatten',
#   'patch_embed.transpose',
#   'patch_embed.norm',
#   'pos_embed',
#   'cls_token',
#   'getattr',
#   'getitem',
#   'expand',
#   'cat',
#   'add',
#   'pos_drop',
#   'patch_drop',
#   'norm_pre',
#   'blocks.0.norm1.blocks_0_norm1_weight',
#   'blocks.0.norm1.blocks_0_norm1_bias',
#   'blocks.0.norm1.layer_norm',
#   'blocks.0.attn.getattr',
#   'blocks.0.attn.getitem',
#   'blocks.0.attn.getitem_1',
#   'blocks.0.attn.getitem_2',
#   'blocks.0.attn.qkv',
#   'blocks.0.attn.reshape',
#   'blocks.0.attn.permute',
#   'blocks.0.attn.unbind',
#   'blocks.0.attn.getitem_3',
#   'blocks.0.attn.getitem_4',
#   'blocks.0.attn.getitem_5',
#   'blocks.0.attn.q_norm',
#   'blocks.0.attn.k_norm',
#   'blocks.0.attn.scaled_dot_product_attention',
#   'blocks.0.attn.transpose',
#   'blocks.0.attn.reshape_1',
#   'blocks.0.attn.norm',
#   'blocks.0.attn.proj',
#   'blocks.0.attn.proj_drop',
#   'blocks.0.ls1',
#   'blocks.0.drop_path1',
#   'blocks.0.add',
#   'blocks.0.norm2.blocks_0_norm2_weight',
#   'blocks.0.norm2.blocks_0_norm2_bias',
#   'blocks.0.norm2.layer_norm',
#   'blocks.0.mlp.fc1',
#   'blocks.0.mlp.act',
#   'blocks.0.mlp.drop1',
#   'blocks.0.mlp.norm',
#   'blocks.0.mlp.fc2',
#   'blocks.0.mlp.drop2',
#   'blocks.0.ls2',
#   'blocks.0.drop_path2',
#   'blocks.0.add_1',
#   'blocks.1.norm1.blocks_1_norm1_weight',
#   'blocks.1.norm1.blocks_1_norm1_bias',
#   'blocks.1.norm1.layer_norm',
#   'blocks.1.attn.getattr',
#   'blocks.1.attn.getitem',
#   'blocks.1.attn.getitem_1',
#   'blocks.1.attn.getitem_2',
#   'blocks.1.attn.qkv',
#   'blocks.1.attn.reshape',
#   'blocks.1.attn.permute',
#   'blocks.1.attn.unbind',
#   'blocks.1.attn.getitem_3',
#   'blocks.1.attn.getitem_4',
#   'blocks.1.attn.getitem_5',
#   'blocks.1.attn.q_norm',
#   'blocks.1.attn.k_norm',
#   'blocks.1.attn.scaled_dot_product_attention',
#   'blocks.1.attn.transpose',
#   'blocks.1.attn.reshape_1',
#   'blocks.1.attn.norm',
#   'blocks.1.attn.proj',
#   'blocks.1.attn.proj_drop',
#   'blocks.1.ls1',
#   'blocks.1.drop_path1',
#   'blocks.1.add',
#   'blocks.1.norm2.blocks_1_norm2_weight',
#   'blocks.1.norm2.blocks_1_norm2_bias',
#   'blocks.1.norm2.layer_norm',
#   'blocks.1.mlp.fc1',
#   'blocks.1.mlp.act',
#   'blocks.1.mlp.drop1',
#   'blocks.1.mlp.norm',
#   'blocks.1.mlp.fc2',
#   'blocks.1.mlp.drop2',
#   'blocks.1.ls2',
#   'blocks.1.drop_path2',
#   'blocks.1.add_1',
#   'blocks.2.norm1.blocks_2_norm1_weight',
#   'blocks.2.norm1.blocks_2_norm1_bias',
#   'blocks.2.norm1.layer_norm',
#   'blocks.2.attn.getattr',
#   'blocks.2.attn.getitem',
#   'blocks.2.attn.getitem_1',
#   'blocks.2.attn.getitem_2',
#   'blocks.2.attn.qkv',
#   'blocks.2.attn.reshape',
#   'blocks.2.attn.permute',
#   'blocks.2.attn.unbind',
#   'blocks.2.attn.getitem_3',
#   'blocks.2.attn.getitem_4',
#   'blocks.2.attn.getitem_5',
#   'blocks.2.attn.q_norm',
#   'blocks.2.attn.k_norm',
#   'blocks.2.attn.scaled_dot_product_attention',
#   'blocks.2.attn.transpose',
#   'blocks.2.attn.reshape_1',
#   'blocks.2.attn.norm',
#   'blocks.2.attn.proj',
#   'blocks.2.attn.proj_drop',
#   'blocks.2.ls1',
#   'blocks.2.drop_path1',
#   'blocks.2.add',
#   'blocks.2.norm2.blocks_2_norm2_weight',
#   'blocks.2.norm2.blocks_2_norm2_bias',
#   'blocks.2.norm2.layer_norm',
#   'blocks.2.mlp.fc1',
#   'blocks.2.mlp.act',
#   'blocks.2.mlp.drop1',
#   'blocks.2.mlp.norm',
#   'blocks.2.mlp.fc2',
#   'blocks.2.mlp.drop2',
#   'blocks.2.ls2',
#   'blocks.2.drop_path2',
#   'blocks.2.add_1',
#   'blocks.3.norm1.blocks_3_norm1_weight',
#   'blocks.3.norm1.blocks_3_norm1_bias',
#   'blocks.3.norm1.layer_norm',
#   'blocks.3.attn.getattr',
#   'blocks.3.attn.getitem',
#   'blocks.3.attn.getitem_1',
#   'blocks.3.attn.getitem_2',
#   'blocks.3.attn.qkv',
#   'blocks.3.attn.reshape',
#   'blocks.3.attn.permute',
#   'blocks.3.attn.unbind',
#   'blocks.3.attn.getitem_3',
#   'blocks.3.attn.getitem_4',
#   'blocks.3.attn.getitem_5',
#   'blocks.3.attn.q_norm',
#   'blocks.3.attn.k_norm',
#   'blocks.3.attn.scaled_dot_product_attention',
#   'blocks.3.attn.transpose',
#   'blocks.3.attn.reshape_1',
#   'blocks.3.attn.norm',
#   'blocks.3.attn.proj',
#   'blocks.3.attn.proj_drop',
#   'blocks.3.ls1',
#   'blocks.3.drop_path1',
#   'blocks.3.add',
#   'blocks.3.norm2.blocks_3_norm2_weight',
#   'blocks.3.norm2.blocks_3_norm2_bias',
#   'blocks.3.norm2.layer_norm',
#   'blocks.3.mlp.fc1',
#   'blocks.3.mlp.act',
#   'blocks.3.mlp.drop1',
#   'blocks.3.mlp.norm',
#   'blocks.3.mlp.fc2',
#   'blocks.3.mlp.drop2',
#   'blocks.3.ls2',
#   'blocks.3.drop_path2',
#   'blocks.3.add_1',
#   'blocks.4.norm1.blocks_4_norm1_weight',
#   'blocks.4.norm1.blocks_4_norm1_bias',
#   'blocks.4.norm1.layer_norm',
#   'blocks.4.attn.getattr',
#   'blocks.4.attn.getitem',
#   'blocks.4.attn.getitem_1',
#   'blocks.4.attn.getitem_2',
#   'blocks.4.attn.qkv',
#   'blocks.4.attn.reshape',
#   'blocks.4.attn.permute',
#   'blocks.4.attn.unbind',
#   'blocks.4.attn.getitem_3',
#   'blocks.4.attn.getitem_4',
#   'blocks.4.attn.getitem_5',
#   'blocks.4.attn.q_norm',
#   'blocks.4.attn.k_norm',
#   'blocks.4.attn.scaled_dot_product_attention',
#   'blocks.4.attn.transpose',
#   'blocks.4.attn.reshape_1',
#   'blocks.4.attn.norm',
#   'blocks.4.attn.proj',
#   'blocks.4.attn.proj_drop',
#   'blocks.4.ls1',
#   'blocks.4.drop_path1',
#   'blocks.4.add',
#   'blocks.4.norm2.blocks_4_norm2_weight',
#   'blocks.4.norm2.blocks_4_norm2_bias',
#   'blocks.4.norm2.layer_norm',
#   'blocks.4.mlp.fc1',
#   'blocks.4.mlp.act',
#   'blocks.4.mlp.drop1',
#   'blocks.4.mlp.norm',
#   'blocks.4.mlp.fc2',
#   'blocks.4.mlp.drop2',
#   'blocks.4.ls2',
#   'blocks.4.drop_path2',
#   'blocks.4.add_1',
#   'blocks.5.norm1.blocks_5_norm1_weight',
#   'blocks.5.norm1.blocks_5_norm1_bias',
#   'blocks.5.norm1.layer_norm',
#   'blocks.5.attn.getattr',
#   'blocks.5.attn.getitem',
#   'blocks.5.attn.getitem_1',
#   'blocks.5.attn.getitem_2',
#   'blocks.5.attn.qkv',
#   'blocks.5.attn.reshape',
#   'blocks.5.attn.permute',
#   'blocks.5.attn.unbind',
#   'blocks.5.attn.getitem_3',
#   'blocks.5.attn.getitem_4',
#   'blocks.5.attn.getitem_5',
#   'blocks.5.attn.q_norm',
#   'blocks.5.attn.k_norm',
#   'blocks.5.attn.scaled_dot_product_attention',
#   'blocks.5.attn.transpose',
#   'blocks.5.attn.reshape_1',
#   'blocks.5.attn.norm',
#   'blocks.5.attn.proj',
#   'blocks.5.attn.proj_drop',
#   'blocks.5.ls1',
#   'blocks.5.drop_path1',
#   'blocks.5.add',
#   'blocks.5.norm2.blocks_5_norm2_weight',
#   'blocks.5.norm2.blocks_5_norm2_bias',
#   'blocks.5.norm2.layer_norm',
#   'blocks.5.mlp.fc1',
#   'blocks.5.mlp.act',
#   'blocks.5.mlp.drop1',
#   'blocks.5.mlp.norm',
#   'blocks.5.mlp.fc2',
#   'blocks.5.mlp.drop2',
#   'blocks.5.ls2',
#   'blocks.5.drop_path2',
#   'blocks.5.add_1',
#   'blocks.6.norm1.blocks_6_norm1_weight',
#   'blocks.6.norm1.blocks_6_norm1_bias',
#   'blocks.6.norm1.layer_norm',
#   'blocks.6.attn.getattr',
#   'blocks.6.attn.getitem',
#   'blocks.6.attn.getitem_1',
#   'blocks.6.attn.getitem_2',
#   'blocks.6.attn.qkv',
#   'blocks.6.attn.reshape',
#   'blocks.6.attn.permute',
#   'blocks.6.attn.unbind',
#   'blocks.6.attn.getitem_3',
#   'blocks.6.attn.getitem_4',
#   'blocks.6.attn.getitem_5',
#   'blocks.6.attn.q_norm',
#   'blocks.6.attn.k_norm',
#   'blocks.6.attn.scaled_dot_product_attention',
#   'blocks.6.attn.transpose',
#   'blocks.6.attn.reshape_1',
#   'blocks.6.attn.norm',
#   'blocks.6.attn.proj',
#   'blocks.6.attn.proj_drop',
#   'blocks.6.ls1',
#   'blocks.6.drop_path1',
#   'blocks.6.add',
#   'blocks.6.norm2.blocks_6_norm2_weight',
#   'blocks.6.norm2.blocks_6_norm2_bias',
#   'blocks.6.norm2.layer_norm',
#   'blocks.6.mlp.fc1',
#   'blocks.6.mlp.act',
#   'blocks.6.mlp.drop1',
#   'blocks.6.mlp.norm',
#   'blocks.6.mlp.fc2',
#   'blocks.6.mlp.drop2',
#   'blocks.6.ls2',
#   'blocks.6.drop_path2',
#   'blocks.6.add_1',
#   'blocks.7.norm1.blocks_7_norm1_weight',
#   'blocks.7.norm1.blocks_7_norm1_bias',
#   'blocks.7.norm1.layer_norm',
#   'blocks.7.attn.getattr',
#   'blocks.7.attn.getitem',
#   'blocks.7.attn.getitem_1',
#   'blocks.7.attn.getitem_2',
#   'blocks.7.attn.qkv',
#   'blocks.7.attn.reshape',
#   'blocks.7.attn.permute',
#   'blocks.7.attn.unbind',
#   'blocks.7.attn.getitem_3',
#   'blocks.7.attn.getitem_4',
#   'blocks.7.attn.getitem_5',
#   'blocks.7.attn.q_norm',
#   'blocks.7.attn.k_norm',
#   'blocks.7.attn.scaled_dot_product_attention',
#   'blocks.7.attn.transpose',
#   'blocks.7.attn.reshape_1',
#   'blocks.7.attn.norm',
#   'blocks.7.attn.proj',
#   'blocks.7.attn.proj_drop',
#   'blocks.7.ls1',
#   'blocks.7.drop_path1',
#   'blocks.7.add',
#   'blocks.7.norm2.blocks_7_norm2_weight',
#   'blocks.7.norm2.blocks_7_norm2_bias',
#   'blocks.7.norm2.layer_norm',
#   'blocks.7.mlp.fc1',
#   'blocks.7.mlp.act',
#   'blocks.7.mlp.drop1',
#   'blocks.7.mlp.norm',
#   'blocks.7.mlp.fc2',
#   'blocks.7.mlp.drop2',
#   'blocks.7.ls2',
#   'blocks.7.drop_path2',
#   'blocks.7.add_1',
#   'blocks.8.norm1.blocks_8_norm1_weight',
#   'blocks.8.norm1.blocks_8_norm1_bias',
#   'blocks.8.norm1.layer_norm',
#   'blocks.8.attn.getattr',
#   'blocks.8.attn.getitem',
#   'blocks.8.attn.getitem_1',
#   'blocks.8.attn.getitem_2',
#   'blocks.8.attn.qkv',
#   'blocks.8.attn.reshape',
#   'blocks.8.attn.permute',
#   'blocks.8.attn.unbind',
#   'blocks.8.attn.getitem_3',
#   'blocks.8.attn.getitem_4',
#   'blocks.8.attn.getitem_5',
#   'blocks.8.attn.q_norm',
#   'blocks.8.attn.k_norm',
#   'blocks.8.attn.scaled_dot_product_attention',
#   'blocks.8.attn.transpose',
#   'blocks.8.attn.reshape_1',
#   'blocks.8.attn.norm',
#   'blocks.8.attn.proj',
#   'blocks.8.attn.proj_drop',
#   'blocks.8.ls1',
#   'blocks.8.drop_path1',
#   'blocks.8.add',
#   'blocks.8.norm2.blocks_8_norm2_weight',
#   'blocks.8.norm2.blocks_8_norm2_bias',
#   'blocks.8.norm2.layer_norm',
#   'blocks.8.mlp.fc1',
#   'blocks.8.mlp.act',
#   'blocks.8.mlp.drop1',
#   'blocks.8.mlp.norm',
#   'blocks.8.mlp.fc2',
#   'blocks.8.mlp.drop2',
#   'blocks.8.ls2',
#   'blocks.8.drop_path2',
#   'blocks.8.add_1',
#   'blocks.9.norm1.blocks_9_norm1_weight',
#   'blocks.9.norm1.blocks_9_norm1_bias',
#   'blocks.9.norm1.layer_norm',
#   'blocks.9.attn.getattr',
#   'blocks.9.attn.getitem',
#   'blocks.9.attn.getitem_1',
#   'blocks.9.attn.getitem_2',
#   'blocks.9.attn.qkv',
#   'blocks.9.attn.reshape',
#   'blocks.9.attn.permute',
#   'blocks.9.attn.unbind',
#   'blocks.9.attn.getitem_3',
#   'blocks.9.attn.getitem_4',
#   'blocks.9.attn.getitem_5',
#   'blocks.9.attn.q_norm',
#   'blocks.9.attn.k_norm',
#   'blocks.9.attn.scaled_dot_product_attention',
#   'blocks.9.attn.transpose',
#   'blocks.9.attn.reshape_1',
#   'blocks.9.attn.norm',
#   'blocks.9.attn.proj',
#   'blocks.9.attn.proj_drop',
#   'blocks.9.ls1',
#   'blocks.9.drop_path1',
#   'blocks.9.add',
#   'blocks.9.norm2.blocks_9_norm2_weight',
#   'blocks.9.norm2.blocks_9_norm2_bias',
#   'blocks.9.norm2.layer_norm',
#   'blocks.9.mlp.fc1',
#   'blocks.9.mlp.act',
#   'blocks.9.mlp.drop1',
#   'blocks.9.mlp.norm',
#   'blocks.9.mlp.fc2',
#   'blocks.9.mlp.drop2',
#   'blocks.9.ls2',
#   'blocks.9.drop_path2',
#   'blocks.9.add_1',
#   'blocks.10.norm1.blocks_10_norm1_weight',
#   'blocks.10.norm1.blocks_10_norm1_bias',
#   'blocks.10.norm1.layer_norm',
#   'blocks.10.attn.getattr',
#   'blocks.10.attn.getitem',
#   'blocks.10.attn.getitem_1',
#   'blocks.10.attn.getitem_2',
#   'blocks.10.attn.qkv',
#   'blocks.10.attn.reshape',
#   'blocks.10.attn.permute',
#   'blocks.10.attn.unbind',
#   'blocks.10.attn.getitem_3',
#   'blocks.10.attn.getitem_4',
#   'blocks.10.attn.getitem_5',
#   'blocks.10.attn.q_norm',
#   'blocks.10.attn.k_norm',
#   'blocks.10.attn.scaled_dot_product_attention',
#   'blocks.10.attn.transpose',
#   'blocks.10.attn.reshape_1',
#   'blocks.10.attn.norm',
#   'blocks.10.attn.proj',
#   'blocks.10.attn.proj_drop',
#   'blocks.10.ls1',
#   'blocks.10.drop_path1',
#   'blocks.10.add',
#   'blocks.10.norm2.blocks_10_norm2_weight',
#   'blocks.10.norm2.blocks_10_norm2_bias',
#   'blocks.10.norm2.layer_norm',
#   'blocks.10.mlp.fc1',
#   'blocks.10.mlp.act',
#   'blocks.10.mlp.drop1',
#   'blocks.10.mlp.norm',
#   'blocks.10.mlp.fc2',
#   'blocks.10.mlp.drop2',
#   'blocks.10.ls2',
#   'blocks.10.drop_path2',
#   'blocks.10.add_1',
#   'blocks.11.norm1.blocks_11_norm1_weight',
#   'blocks.11.norm1.blocks_11_norm1_bias',
#   'blocks.11.norm1.layer_norm',
#   'blocks.11.attn.getattr',
#   'blocks.11.attn.getitem',
#   'blocks.11.attn.getitem_1',
#   'blocks.11.attn.getitem_2',
#   'blocks.11.attn.qkv',
#   'blocks.11.attn.reshape',
#   'blocks.11.attn.permute',
#   'blocks.11.attn.unbind',
#   'blocks.11.attn.getitem_3',
#   'blocks.11.attn.getitem_4',
#   'blocks.11.attn.getitem_5',
#   'blocks.11.attn.q_norm',
#   'blocks.11.attn.k_norm',
#   'blocks.11.attn.scaled_dot_product_attention',
#   'blocks.11.attn.transpose',
#   'blocks.11.attn.reshape_1',
#   'blocks.11.attn.norm',
#   'blocks.11.attn.proj',
#   'blocks.11.attn.proj_drop',
#   'blocks.11.ls1',
#   'blocks.11.drop_path1',
#   'blocks.11.add',
#   'blocks.11.norm2.blocks_11_norm2_weight',
#   'blocks.11.norm2.blocks_11_norm2_bias',
#   'blocks.11.norm2.layer_norm',
#   'blocks.11.mlp.fc1',
#   'blocks.11.mlp.act',
#   'blocks.11.mlp.drop1',
#   'blocks.11.mlp.norm',
#   'blocks.11.mlp.fc2',
#   'blocks.11.mlp.drop2',
#   'blocks.11.ls2',
#   'blocks.11.drop_path2',
#   'blocks.11.add_1',
#   'blocks.12.norm1.blocks_12_norm1_weight',
#   'blocks.12.norm1.blocks_12_norm1_bias',
#   'blocks.12.norm1.layer_norm',
#   'blocks.12.attn.getattr',
#   'blocks.12.attn.getitem',
#   'blocks.12.attn.getitem_1',
#   'blocks.12.attn.getitem_2',
#   'blocks.12.attn.qkv',
#   'blocks.12.attn.reshape',
#   'blocks.12.attn.permute',
#   'blocks.12.attn.unbind',
#   'blocks.12.attn.getitem_3',
#   'blocks.12.attn.getitem_4',
#   'blocks.12.attn.getitem_5',
#   'blocks.12.attn.q_norm',
#   'blocks.12.attn.k_norm',
#   'blocks.12.attn.scaled_dot_product_attention',
#   'blocks.12.attn.transpose',
#   'blocks.12.attn.reshape_1',
#   'blocks.12.attn.norm',
#   'blocks.12.attn.proj',
#   'blocks.12.attn.proj_drop',
#   'blocks.12.ls1',
#   'blocks.12.drop_path1',
#   'blocks.12.add',
#   'blocks.12.norm2.blocks_12_norm2_weight',
#   'blocks.12.norm2.blocks_12_norm2_bias',
#   'blocks.12.norm2.layer_norm',
#   'blocks.12.mlp.fc1',
#   'blocks.12.mlp.act',
#   'blocks.12.mlp.drop1',
#   'blocks.12.mlp.norm',
#   'blocks.12.mlp.fc2',
#   'blocks.12.mlp.drop2',
#   'blocks.12.ls2',
#   'blocks.12.drop_path2',
#   'blocks.12.add_1',
#   'blocks.13.norm1.blocks_13_norm1_weight',
#   'blocks.13.norm1.blocks_13_norm1_bias',
#   'blocks.13.norm1.layer_norm',
#   'blocks.13.attn.getattr',
#   'blocks.13.attn.getitem',
#   'blocks.13.attn.getitem_1',
#   'blocks.13.attn.getitem_2',
#   'blocks.13.attn.qkv',
#   'blocks.13.attn.reshape',
#   'blocks.13.attn.permute',
#   'blocks.13.attn.unbind',
#   'blocks.13.attn.getitem_3',
#   'blocks.13.attn.getitem_4',
#   'blocks.13.attn.getitem_5',
#   'blocks.13.attn.q_norm',
#   'blocks.13.attn.k_norm',
#   'blocks.13.attn.scaled_dot_product_attention',
#   'blocks.13.attn.transpose',
#   'blocks.13.attn.reshape_1',
#   'blocks.13.attn.norm',
#   'blocks.13.attn.proj',
#   'blocks.13.attn.proj_drop',
#   'blocks.13.ls1',
#   'blocks.13.drop_path1',
#   'blocks.13.add',
#   'blocks.13.norm2.blocks_13_norm2_weight',
#   'blocks.13.norm2.blocks_13_norm2_bias',
#   'blocks.13.norm2.layer_norm',
#   'blocks.13.mlp.fc1',
#   'blocks.13.mlp.act',
#   'blocks.13.mlp.drop1',
#   'blocks.13.mlp.norm',
#   'blocks.13.mlp.fc2',
#   'blocks.13.mlp.drop2',
#   'blocks.13.ls2',
#   'blocks.13.drop_path2',
#   'blocks.13.add_1',
#   'blocks.14.norm1.blocks_14_norm1_weight',
#   'blocks.14.norm1.blocks_14_norm1_bias',
#   'blocks.14.norm1.layer_norm',
#   'blocks.14.attn.getattr',
#   'blocks.14.attn.getitem',
#   'blocks.14.attn.getitem_1',
#   'blocks.14.attn.getitem_2',
#   'blocks.14.attn.qkv',
#   'blocks.14.attn.reshape',
#   'blocks.14.attn.permute',
#   'blocks.14.attn.unbind',
#   'blocks.14.attn.getitem_3',
#   'blocks.14.attn.getitem_4',
#   'blocks.14.attn.getitem_5',
#   'blocks.14.attn.q_norm',
#   'blocks.14.attn.k_norm',
#   'blocks.14.attn.scaled_dot_product_attention',
#   'blocks.14.attn.transpose',
#   'blocks.14.attn.reshape_1',
#   'blocks.14.attn.norm',
#   'blocks.14.attn.proj',
#   'blocks.14.attn.proj_drop',
#   'blocks.14.ls1',
#   'blocks.14.drop_path1',
#   'blocks.14.add',
#   'blocks.14.norm2.blocks_14_norm2_weight',
#   'blocks.14.norm2.blocks_14_norm2_bias',
#   'blocks.14.norm2.layer_norm',
#   'blocks.14.mlp.fc1',
#   'blocks.14.mlp.act',
#   'blocks.14.mlp.drop1',
#   'blocks.14.mlp.norm',
#   'blocks.14.mlp.fc2',
#   'blocks.14.mlp.drop2',
#   'blocks.14.ls2',
#   'blocks.14.drop_path2',
#   'blocks.14.add_1',
#   'blocks.15.norm1.blocks_15_norm1_weight',
#   'blocks.15.norm1.blocks_15_norm1_bias',
#   'blocks.15.norm1.layer_norm',
#   'blocks.15.attn.getattr',
#   'blocks.15.attn.getitem',
#   'blocks.15.attn.getitem_1',
#   'blocks.15.attn.getitem_2',
#   'blocks.15.attn.qkv',
#   'blocks.15.attn.reshape',
#   'blocks.15.attn.permute',
#   'blocks.15.attn.unbind',
#   'blocks.15.attn.getitem_3',
#   'blocks.15.attn.getitem_4',
#   'blocks.15.attn.getitem_5',
#   'blocks.15.attn.q_norm',
#   'blocks.15.attn.k_norm',
#   'blocks.15.attn.scaled_dot_product_attention',
#   'blocks.15.attn.transpose',
#   'blocks.15.attn.reshape_1',
#   'blocks.15.attn.norm',
#   'blocks.15.attn.proj',
#   'blocks.15.attn.proj_drop',
#   'blocks.15.ls1',
#   'blocks.15.drop_path1',
#   'blocks.15.add',
#   'blocks.15.norm2.blocks_15_norm2_weight',
#   'blocks.15.norm2.blocks_15_norm2_bias',
#   'blocks.15.norm2.layer_norm',
#   'blocks.15.mlp.fc1',
#   'blocks.15.mlp.act',
#   'blocks.15.mlp.drop1',
#   'blocks.15.mlp.norm',
#   'blocks.15.mlp.fc2',
#   'blocks.15.mlp.drop2',
#   'blocks.15.ls2',
#   'blocks.15.drop_path2',
#   'blocks.15.add_1',
#   'blocks.16.norm1.blocks_16_norm1_weight',
#   'blocks.16.norm1.blocks_16_norm1_bias',
#   'blocks.16.norm1.layer_norm',
#   'blocks.16.attn.getattr',
#   'blocks.16.attn.getitem',
#   'blocks.16.attn.getitem_1',
#   'blocks.16.attn.getitem_2',
#   'blocks.16.attn.qkv',
#   'blocks.16.attn.reshape',
#   'blocks.16.attn.permute',
#   'blocks.16.attn.unbind',
#   'blocks.16.attn.getitem_3',
#   'blocks.16.attn.getitem_4',
#   'blocks.16.attn.getitem_5',
#   'blocks.16.attn.q_norm',
#   'blocks.16.attn.k_norm',
#   'blocks.16.attn.scaled_dot_product_attention',
#   'blocks.16.attn.transpose',
#   'blocks.16.attn.reshape_1',
#   'blocks.16.attn.norm',
#   'blocks.16.attn.proj',
#   'blocks.16.attn.proj_drop',
#   'blocks.16.ls1',
#   'blocks.16.drop_path1',
#   'blocks.16.add',
#   'blocks.16.norm2.blocks_16_norm2_weight',
#   'blocks.16.norm2.blocks_16_norm2_bias',
#   'blocks.16.norm2.layer_norm',
#   'blocks.16.mlp.fc1',
#   'blocks.16.mlp.act',
#   'blocks.16.mlp.drop1',
#   'blocks.16.mlp.norm',
#   'blocks.16.mlp.fc2',
#   'blocks.16.mlp.drop2',
#   'blocks.16.ls2',
#   'blocks.16.drop_path2',
#   'blocks.16.add_1',
#   'blocks.17.norm1.blocks_17_norm1_weight',
#   'blocks.17.norm1.blocks_17_norm1_bias',
#   'blocks.17.norm1.layer_norm',
#   'blocks.17.attn.getattr',
#   'blocks.17.attn.getitem',
#   'blocks.17.attn.getitem_1',
#   'blocks.17.attn.getitem_2',
#   'blocks.17.attn.qkv',
#   'blocks.17.attn.reshape',
#   'blocks.17.attn.permute',
#   'blocks.17.attn.unbind',
#   'blocks.17.attn.getitem_3',
#   'blocks.17.attn.getitem_4',
#   'blocks.17.attn.getitem_5',
#   'blocks.17.attn.q_norm',
#   'blocks.17.attn.k_norm',
#   'blocks.17.attn.scaled_dot_product_attention',
#   'blocks.17.attn.transpose',
#   'blocks.17.attn.reshape_1',
#   'blocks.17.attn.norm',
#   'blocks.17.attn.proj',
#   'blocks.17.attn.proj_drop',
#   'blocks.17.ls1',
#   'blocks.17.drop_path1',
#   'blocks.17.add',
#   'blocks.17.norm2.blocks_17_norm2_weight',
#   'blocks.17.norm2.blocks_17_norm2_bias',
#   'blocks.17.norm2.layer_norm',
#   'blocks.17.mlp.fc1',
#   'blocks.17.mlp.act',
#   'blocks.17.mlp.drop1',
#   'blocks.17.mlp.norm',
#   'blocks.17.mlp.fc2',
#   'blocks.17.mlp.drop2',
#   'blocks.17.ls2',
#   'blocks.17.drop_path2',
#   'blocks.17.add_1',
#   'blocks.18.norm1.blocks_18_norm1_weight',
#   'blocks.18.norm1.blocks_18_norm1_bias',
#   'blocks.18.norm1.layer_norm',
#   'blocks.18.attn.getattr',
#   'blocks.18.attn.getitem',
#   'blocks.18.attn.getitem_1',
#   'blocks.18.attn.getitem_2',
#   'blocks.18.attn.qkv',
#   'blocks.18.attn.reshape',
#   'blocks.18.attn.permute',
#   'blocks.18.attn.unbind',
#   'blocks.18.attn.getitem_3',
#   'blocks.18.attn.getitem_4',
#   'blocks.18.attn.getitem_5',
#   'blocks.18.attn.q_norm',
#   'blocks.18.attn.k_norm',
#   'blocks.18.attn.scaled_dot_product_attention',
#   'blocks.18.attn.transpose',
#   'blocks.18.attn.reshape_1',
#   'blocks.18.attn.norm',
#   'blocks.18.attn.proj',
#   'blocks.18.attn.proj_drop',
#   'blocks.18.ls1',
#   'blocks.18.drop_path1',
#   'blocks.18.add',
#   'blocks.18.norm2.blocks_18_norm2_weight',
#   'blocks.18.norm2.blocks_18_norm2_bias',
#   'blocks.18.norm2.layer_norm',
#   'blocks.18.mlp.fc1',
#   'blocks.18.mlp.act',
#   'blocks.18.mlp.drop1',
#   'blocks.18.mlp.norm',
#   'blocks.18.mlp.fc2',
#   'blocks.18.mlp.drop2',
#   'blocks.18.ls2',
#   'blocks.18.drop_path2',
#   'blocks.18.add_1',
#   'blocks.19.norm1.blocks_19_norm1_weight',
#   'blocks.19.norm1.blocks_19_norm1_bias',
#   'blocks.19.norm1.layer_norm',
#   'blocks.19.attn.getattr',
#   'blocks.19.attn.getitem',
#   'blocks.19.attn.getitem_1',
#   'blocks.19.attn.getitem_2',
#   'blocks.19.attn.qkv',
#   'blocks.19.attn.reshape',
#   'blocks.19.attn.permute',
#   'blocks.19.attn.unbind',
#   'blocks.19.attn.getitem_3',
#   'blocks.19.attn.getitem_4',
#   'blocks.19.attn.getitem_5',
#   'blocks.19.attn.q_norm',
#   'blocks.19.attn.k_norm',
#   'blocks.19.attn.scaled_dot_product_attention',
#   'blocks.19.attn.transpose',
#   'blocks.19.attn.reshape_1',
#   'blocks.19.attn.norm',
#   'blocks.19.attn.proj',
#   'blocks.19.attn.proj_drop',
#   'blocks.19.ls1',
#   'blocks.19.drop_path1',
#   'blocks.19.add',
#   'blocks.19.norm2.blocks_19_norm2_weight',
#   'blocks.19.norm2.blocks_19_norm2_bias',
#   'blocks.19.norm2.layer_norm',
#   'blocks.19.mlp.fc1',
#   'blocks.19.mlp.act',
#   'blocks.19.mlp.drop1',
#   'blocks.19.mlp.norm',
#   'blocks.19.mlp.fc2',
#   'blocks.19.mlp.drop2',
#   'blocks.19.ls2',
#   'blocks.19.drop_path2',
#   'blocks.19.add_1',
#   'blocks.20.norm1.blocks_20_norm1_weight',
#   'blocks.20.norm1.blocks_20_norm1_bias',
#   'blocks.20.norm1.layer_norm',
#   'blocks.20.attn.getattr',
#   'blocks.20.attn.getitem',
#   'blocks.20.attn.getitem_1',
#   'blocks.20.attn.getitem_2',
#   'blocks.20.attn.qkv',
#   'blocks.20.attn.reshape',
#   'blocks.20.attn.permute',
#   'blocks.20.attn.unbind',
#   'blocks.20.attn.getitem_3',
#   'blocks.20.attn.getitem_4',
#   'blocks.20.attn.getitem_5',
#   'blocks.20.attn.q_norm',
#   'blocks.20.attn.k_norm',
#   'blocks.20.attn.scaled_dot_product_attention',
#   'blocks.20.attn.transpose',
#   'blocks.20.attn.reshape_1',
#   'blocks.20.attn.norm',
#   'blocks.20.attn.proj',
#   'blocks.20.attn.proj_drop',
#   'blocks.20.ls1',
#   'blocks.20.drop_path1',
#   'blocks.20.add',
#   'blocks.20.norm2.blocks_20_norm2_weight',
#   'blocks.20.norm2.blocks_20_norm2_bias',
#   'blocks.20.norm2.layer_norm',
#   'blocks.20.mlp.fc1',
#   'blocks.20.mlp.act',
#   'blocks.20.mlp.drop1',
#   'blocks.20.mlp.norm',
#   'blocks.20.mlp.fc2',
#   'blocks.20.mlp.drop2',
#   'blocks.20.ls2',
#   'blocks.20.drop_path2',
#   'blocks.20.add_1',
#   'blocks.21.norm1.blocks_21_norm1_weight',
#   'blocks.21.norm1.blocks_21_norm1_bias',
#   'blocks.21.norm1.layer_norm',
#   'blocks.21.attn.getattr',
#   'blocks.21.attn.getitem',
#   'blocks.21.attn.getitem_1',
#   'blocks.21.attn.getitem_2',
#   'blocks.21.attn.qkv',
#   'blocks.21.attn.reshape',
#   'blocks.21.attn.permute',
#   'blocks.21.attn.unbind',
#   'blocks.21.attn.getitem_3',
#   'blocks.21.attn.getitem_4',
#   'blocks.21.attn.getitem_5',
#   'blocks.21.attn.q_norm',
#   'blocks.21.attn.k_norm',
#   'blocks.21.attn.scaled_dot_product_attention',
#   'blocks.21.attn.transpose',
#   'blocks.21.attn.reshape_1',
#   'blocks.21.attn.norm',
#   'blocks.21.attn.proj',
#   'blocks.21.attn.proj_drop',
#   'blocks.21.ls1',
#   'blocks.21.drop_path1',
#   'blocks.21.add',
#   'blocks.21.norm2.blocks_21_norm2_weight',
#   'blocks.21.norm2.blocks_21_norm2_bias',
#   'blocks.21.norm2.layer_norm',
#   'blocks.21.mlp.fc1',
#   'blocks.21.mlp.act',
#   'blocks.21.mlp.drop1',
#   'blocks.21.mlp.norm',
#   'blocks.21.mlp.fc2',
#   'blocks.21.mlp.drop2',
#   'blocks.21.ls2',
#   'blocks.21.drop_path2',
#   'blocks.21.add_1',
#   'blocks.22.norm1.blocks_22_norm1_weight',
#   'blocks.22.norm1.blocks_22_norm1_bias',
#   'blocks.22.norm1.layer_norm',
#   'blocks.22.attn.getattr',
#   'blocks.22.attn.getitem',
#   'blocks.22.attn.getitem_1',
#   'blocks.22.attn.getitem_2',
#   'blocks.22.attn.qkv',
#   'blocks.22.attn.reshape',
#   'blocks.22.attn.permute',
#   'blocks.22.attn.unbind',
#   'blocks.22.attn.getitem_3',
#   'blocks.22.attn.getitem_4',
#   'blocks.22.attn.getitem_5',
#   'blocks.22.attn.q_norm',
#   'blocks.22.attn.k_norm',
#   'blocks.22.attn.scaled_dot_product_attention',
#   'blocks.22.attn.transpose',
#   'blocks.22.attn.reshape_1',
#   'blocks.22.attn.norm',
#   'blocks.22.attn.proj',
#   'blocks.22.attn.proj_drop',
#   'blocks.22.ls1',
#   'blocks.22.drop_path1',
#   'blocks.22.add',
#   'blocks.22.norm2.blocks_22_norm2_weight',
#   'blocks.22.norm2.blocks_22_norm2_bias',
#   'blocks.22.norm2.layer_norm',
#   'blocks.22.mlp.fc1',
#   'blocks.22.mlp.act',
#   'blocks.22.mlp.drop1',
#   'blocks.22.mlp.norm',
#   'blocks.22.mlp.fc2',
#   'blocks.22.mlp.drop2',
#   'blocks.22.ls2',
#   'blocks.22.drop_path2',
#   'blocks.22.add_1',
#   'blocks.23.norm1.blocks_23_norm1_weight',
#   'blocks.23.norm1.blocks_23_norm1_bias',
#   'blocks.23.norm1.layer_norm',
#   'blocks.23.attn.getattr',
#   'blocks.23.attn.getitem',
#   'blocks.23.attn.getitem_1',
#   'blocks.23.attn.getitem_2',
#   'blocks.23.attn.qkv',
#   'blocks.23.attn.reshape',
#   'blocks.23.attn.permute',
#   'blocks.23.attn.unbind',
#   'blocks.23.attn.getitem_3',
#   'blocks.23.attn.getitem_4',
#   'blocks.23.attn.getitem_5',
#   'blocks.23.attn.q_norm',
#   'blocks.23.attn.k_norm',
#   'blocks.23.attn.scaled_dot_product_attention',
#   'blocks.23.attn.transpose',
#   'blocks.23.attn.reshape_1',
#   'blocks.23.attn.norm',
#   'blocks.23.attn.proj',
#   'blocks.23.attn.proj_drop',
#   'blocks.23.ls1',
#   'blocks.23.drop_path1',
#   'blocks.23.add',
#   'blocks.23.norm2.blocks_23_norm2_weight',
#   'blocks.23.norm2.blocks_23_norm2_bias',
#   'blocks.23.norm2.layer_norm',
#   'blocks.23.mlp.fc1',
#   'blocks.23.mlp.act',
#   'blocks.23.mlp.drop1',
#   'blocks.23.mlp.norm',
#   'blocks.23.mlp.fc2',
#   'blocks.23.mlp.drop2',
#   'blocks.23.ls2',
#   'blocks.23.drop_path2',
#   'blocks.23.add_1',
#   'norm.norm_weight',
#   'norm.norm_bias',
#   'norm.layer_norm',
#   'getitem_1',
#   'fc_norm',
#   'head_drop',
#   'head'])

# %%
device = get_device()
transform = get_usual_transform(resize_size=384, normalize=False)

dataset = ImageFolder(
    root=f"{paths['livingstone_lab']}/Stimuli/{cfg.data_folder}/",
    transform=transform,
    is_valid_file=lambda x: not x.endswith("Thumbs.db"), 
    allow_empty=True, 
)
mapping_idx = map_image_order_from_ann_to_monkey(paths, cfg.monkey_name, cfg.date, dataset)
dataloader = DataLoader(dataset, batch_size=cfg.batch_size, shuffle=True)
model = load_timm_model(cfg.model_name, 384, device)
img_feats_extraction(paths, 0, cfg.layer_name, cfg.model_name, model, dataloader, mapping_idx, cfg.monkey_name, cfg.date, cfg.n_components, device)
# Out:
# 15:23:01 - device being used: mps
# 15:23:09 - rank 0 loaded batch 0 of shape (2, 590848)
# 15:23:09 - rank 0 loaded batch 1 of shape (2, 590848)
# 15:23:09 - rank 0 loaded batch 2 of shape (2, 590848)
# 15:23:09 - rank 0 loaded batch 3 of shape (2, 590848)
# 15:23:10 - rank 0 loaded batch 4 of shape (2, 590848)
# 15:23:10 - rank 0 loaded batch 5 of shape (2, 590848)
# 15:23:10 - rank 0 loaded batch 6 of shape (2, 590848)
# 15:23:10 - rank 0 loaded batch 7 of shape (2, 590848)
# 15:23:11 - rank 0 loaded batch 8 of shape (2, 590848)
# 15:23:11 - rank 0 loaded batch 9 of shape (2, 590848)
# 15:23:11 - rank 0 loaded batch 10 of shape (2, 590848)
# 15:23:11 - rank 0 loaded batch 11 of shape (2, 590848)
# 15:23:12 - rank 0 loaded batch 12 of shape (2, 590848)
# 15:23:12 - rank 0 loaded batch 13 of shape (2, 590848)
# 15:23:12 - rank 0 loaded batch 14 of shape (2, 590848)
# 15:23:12 - rank 0 loaded batch 15 of shape (2, 590848)
# 15:23:13 - rank 0 loaded batch 16 of shape (2, 590848)
# 15:23:13 - rank 0 loaded batch 17 of shape (2, 590848)
# 15:23:13 - rank 0 loaded batch 18 of shape (2, 590848)
# 15:23:13 - rank 0 loaded batch 19 of shape (2, 590848)
# 15:23:14 - rank 0 loaded batch 20 of shape (2, 590848)
# 15:23:14 - rank 0 loaded batch 21 of shape (2, 590848)
# 15:23:14 - rank 0 loaded batch 22 of shape (2, 590848)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 13
#      11 dataloader = DataLoader(dataset, batch_size=2, shuffle=True)
#      12 model = load_timm_model(cfg.model_name, 384, device)
# ---> 13 img_feats_extraction(paths, 0, cfg.layer_name, cfg.model_name, model, dataloader, mapping_idx, cfg.monkey_name, cfg.date, cfg.n_components, device)
#
# File ~/Desktop/temporal_context/python_scripts/src/image_processing/computational_models.py:509, in img_feats_extraction(paths, rank, layer_name, model_name, model, dataloader, mapping_idx, monkey_name, date, n_components, device)
#     507 else:
#     508     feature_extractor = create_feature_extractor(model, return_nodes=[layer_name]).to(device)
# --> 509     all_feats = img_dataloader_feature_extraction_loop(rank, feature_extractor, layer_name, dataloader, device)
#     510     all_feats = all_feats[mapping_idx, :]
#     511     RDM_vec = create_RDM(all_feats.T)
#
# File ~/Desktop/temporal_context/python_scripts/src/image_processing/computational_models.py:460, in img_dataloader_feature_extraction_loop(rank, feature_extractor, layer_name, dataloader, device)
#     458 for batch_idx, (images, labels) in enumerate(dataloader):
#     459     feats =feature_extractor(images.to(device))[layer_name]
# --> 460     feats = feats.reshape(feats.size(0), -1).cpu().numpy()
#     461     all_feats.append(feats)
#     462     print_wise(f"loaded batch {batch_idx} of shape {feats.shape}", rank=rank)
#
# KeyboardInterrupt:

# %% [markdown]
# create dataset and transform

# %%
transform = get_usual_transform(resize_size=384, normalize=False)

dataset = ImageFolder(
    root=f"{paths['livingstone_lab']}/Stimuli/{cfg.data_folder}/",
    transform=transform,
    is_valid_file=lambda x: not x.endswith("Thumbs.db"), 
    allow_empty=True, 
)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %% [markdown]
# load model

# %%
model = load_timm_model(cfg.model_name, 384, device)

# %% [markdown]
# loop through dataset

# %% [markdown]
# create a list to keep the indices of presentation of the images (see presentation order and mapping)

# %%
allimgs_path = f"{paths['livingstone_lab']}/tiziano/data/{cfg.monkey_name}_allimages{cfg.date}.mat"
with h5py.File(allimgs_path, "r") as f:
    refs = f["allimages"][:]      # shape (N, 1) of object refs
    image_names = decode_matlab_strings(f, refs)
    image_names = list(dict.fromkeys(image_names)) 
presentation_order = [os.path.basename(path) for path, _ in dataset.samples]
print(presentation_order)
print(image_names)
# Create a mapping from list_b to list_a
mapping_idx = [presentation_order.index(x) for x in image_names]
mapped_order = [presentation_order[i] for i in mapping_idx]
print(mapped_order)
# Out:
# ['BigAnimate_01.jpg', 'BigAnimate_02.jpg', 'BigAnimate_03.jpg', 'BigAnimate_04.jpg', 'BigAnimate_05.jpg', 'BigAnimate_06.jpg', 'BigAnimate_07.jpg', 'BigAnimate_08.jpg', 'BigAnimate_09.jpg', 'BigAnimate_10.jpg', 'BigAnimate_11.jpg', 'BigAnimate_12.jpg', 'BigAnimate_13.jpg', 'BigAnimate_14.jpg', 'BigAnimate_15.jpg', 'BigAnimate_16.jpg', 'BigAnimate_17.jpg', 'BigAnimate_18.jpg', 'BigAnimate_19.jpg', 'BigAnimate_20.jpg', 'BigAnimate_21.jpg', 'BigAnimate_22.jpg', 'BigAnimate_23.jpg', 'BigAnimate_24.jpg', 'BigAnimate_25.jpg', 'BigAnimate_26.jpg', 'BigAnimate_27.jpg', 'BigAnimate_28.jpg', 'BigAnimate_29.jpg', 'BigAnimate_30.jpg', 'BigAnimate_31.jpg', 'BigAnimate_32.jpg', 'BigAnimate_33.jpg', 'BigAnimate_34.jpg', 'BigAnimate_35.jpg', 'BigAnimate_36.jpg', 'BigAnimate_37.jpg', 'BigAnimate_38.jpg', 'BigAnimate_39.jpg', 'BigAnimate_40.jpg', 'BigAnimate_41.jpg', 'BigAnimate_42.jpg', 'BigAnimate_43.jpg', 'BigAnimate_44.jpg', 'BigAnimate_45.jpg', 'BigAnimate_46.jpg', 'BigAnimate_47.jpg', 'BigAnimate_48.jpg', 'BigAnimate_49.jpg', 'BigAnimate_50.jpg', 'BigAnimate_51.jpg', 'BigAnimate_52.jpg', 'BigAnimate_53.jpg', 'BigAnimate_54.jpg', 'BigAnimate_55.jpg', 'BigAnimate_56.jpg', 'BigAnimate_57.jpg', 'BigAnimate_58.jpg', 'BigAnimate_59.jpg', 'BigAnimate_60.jpg', 'BigAnimate_61.jpg', 'BigAnimate_62.jpg', 'BigAnimate_63.jpg', 'BigAnimate_64.jpg', 'FFM_001.jpg', 'FFM_002.jpg', 'FFM_003.jpg', 'FFM_004.jpg', 'FFM_005.jpg', 'FFM_006.jpg', 'FFM_007.jpg', 'FFM_008.jpg', 'FFM_009.jpg', 'FFM_010.jpg', 'FFM_011.jpg', 'FFM_012.jpg', 'FFM_013.jpg', 'FFM_014.jpg', 'FFM_015.jpg', 'FFM_016.jpg', 'FFM_017.jpg', 'FFM_018.jpg', 'FFM_019.jpg', 'FFM_020.jpg', 'FFM_021.jpg', 'FFM_022.jpg', 'FFM_023.jpg', 'FFM_024.jpg', 'FFM_025.jpg', 'FFM_026.jpg', 'FFM_027.jpg', 'FFM_028.jpg', 'FFM_029.jpg', 'FFM_030.jpg', 'FFM_031.jpg', 'FFM_032.jpg', 'FFM_033.jpg', 'FFM_034.jpg', 'FFM_035.jpg', 'FFM_036.jpg', 'FFM_037.jpg', 'FFM_038.jpg', 'FFM_039.jpg', 'FFM_040.jpg', 'FFM_041.jpg', 'FFM_042.jpg', 'FFM_043.jpg', 'FFM_044.jpg', 'FFM_045.jpg', 'FFM_046.jpg', 'FFM_047.jpg', 'FFM_048.jpg', 'FFM_049.jpg', 'FFM_050.jpg', 'FFM_051.jpg', 'FFM_052.jpg', 'FFM_053.jpg', 'FFM_054.jpg', 'FFM_055.jpg', 'FFM_056.jpg', 'FFM_057.jpg', 'FFM_058.jpg', 'FFM_059.jpg', 'FFM_060.jpg', 'FFM_061.jpg', 'FFM_062.jpg', 'FFM_063.jpg', 'FFM_064.jpg', 'FFM_065.jpg', 'FFM_066.jpg', 'FFM_067.jpg', 'FFM_068.jpg', 'FFM_069.jpg', 'FFM_070.jpg', 'FFM_071.jpg', 'FFM_072.jpg', 'FFM_073.jpg', 'FFM_074.jpg', 'FFM_075.jpg', 'FFM_076.jpg', 'FFM_077.jpg', 'FFM_078.jpg', 'FFM_079.jpg', 'FFM_080.jpg', 'FFM_081.jpg', 'FFM_082.jpg', 'FFM_083.jpg', 'FFM_084.jpg', 'FFM_085.jpg', 'FFM_086.jpg', 'FFM_087.jpg', 'FFM_088.jpg', 'FFM_089.jpg', 'FFM_090.jpg', 'FFM_091.jpg', 'FFM_092.jpg', 'FFM_093.jpg', 'FFM_094.jpg', 'FFM_095.jpg', 'FFM_096.jpg', 'FFM_097.jpg', 'FFM_098.jpg', 'FFM_099.jpg', 'FFM_100.jpg', 'FFM_101.jpg', 'FFM_102.jpg', 'FFM_103.jpg', 'FFM_104.jpg', 'FFM_105.jpg', 'FFM_106.jpg', 'FFM_107.jpg', 'FFM_108.jpg', 'FFM_109.jpg', 'FFM_110.jpg', 'FFM_111.jpg', 'FFM_112.jpg', 'FFM_113.jpg', 'FFM_114.jpg', 'FFM_115.jpg', 'FFM_116.jpg', 'FFM_117.jpg', 'FFM_118.jpg', 'FFM_119.jpg', 'FFM_120.jpg', 'FFM_121.jpg', 'FFM_122.jpg', 'FFM_123.jpg', 'FFM_124.jpg', 'FFM_125.jpg', 'FFM_126.jpg', 'FFM_127.jpg', 'FFM_128.jpg', 'FFM_129.jpg', 'FFM_130.jpg', 'FFM_131.jpg', 'FFM_132.jpg', 'FFM_133.jpg', 'FFM_134.jpg', 'FFM_135.jpg', 'FFM_136.jpg', 'FFM_137.jpg', 'FFM_138.jpg', 'FFM_139.jpg', 'FFM_140.jpg', 'FFM_141.jpg', 'FFM_142.jpg', 'FFM_143.jpg', 'FFM_144.jpg', 'FFM_145.jpg', 'FFM_146.jpg', 'FFM_147.jpg', 'FFM_148.jpg', 'FFM_149.jpg', 'FFM_150.jpg', 'FFM_151.jpg', 'FFM_152.jpg', 'FFM_153.jpg', 'FFM_154.jpg', 'FFM_155.jpg', 'FFM_156.jpg', 'FFM_157.jpg', 'FFM_158.jpg', 'FFM_159.jpg', 'FFM_160.jpg', 'FFM_161.jpg', 'FFM_162.jpg', 'FFM_163.jpg', 'FFM_164.jpg', 'FFM_165.jpg', 'FFM_166.jpg', 'FFM_167.jpg', 'FFM_168.jpg', 'FFM_169.jpg', 'FFM_170.jpg', 'FFM_171.jpg', 'FFM_172.jpg', 'FFM_173.jpg', 'FFM_174.jpg', 'FFM_175.jpg', 'FFM_176.jpg', 'FFM_177.jpg',  ...
# ['pman_4_half.jpg', 'mface_1_hair.jpg', 'FH_176.jpg', 'Sony_Bravia_cellphone_1.jpg', 'jumblefaces_06.jpg', 'BigAnimate_39.jpg', 'rock_015.jpg', 'breadloaf_14.jpg', 'OtherGuy_2_wbkg.jpg', 'pezdispenser_002.jpg', 'mface_5_100white.jpg', 'object_6_bars.jpg', 'mface_7_100white.jpg', 'red_3_barless.jpg', 'bonzai_14.jpg', 'pface_2_tiny.jpg', 'mface_4_bkg_bars.jpg', 'hface_10_hair.jpg', 'trumpet33.jpg', 'musicstand_003.jpg', 'Alei22.jpg', 'FFM_046.jpg', 'FH_66.jpg', 'FFM_165.jpg', 'dts_8.jpg', 'FH_7.jpg', 'pie_003.jpg', 'cooler_015.jpg', 'UFH_187.jpg', 'tennisracquet_04.jpg', 'va-eew.jpg', 'object_6_dots.jpg', 'object_12_100white.jpg', 'UFH_170.jpg', 'monk_4.jpg', 'FH_261.jpg', 'familiarObjects_13.jpg', 'UFH_006.jpg', 'Make-Up-Set-Cake.jpg', 'hface_9_half.jpg', 'familiar_16_bkg_bars.jpg', 'trophy_015.jpg', 'weirdT_7.jpg', 'macaques_21.jpg', 'FH_83.jpg', 'waxseal_001.jpg', 'Parth_Portofino_500.jpg', 'hands_19.jpg', 'familar_12.jpg', 'keynew01.jpg', 'FFM_137.jpg', 'ABEARMASK.jpg', 'carabiners_012.jpg', 'pman_9_half.jpg', 'bill_013.jpg', 'familiar_14_gray.jpg', 'soapdispenser_001.jpg', 'FM_83.jpg', 'profiles_09.jpg', 'motorola c115-thumb.jpg', 'familiar_8_bkg.jpg', 'grapes_002.jpg', 'plate_002.jpg', 'pface_3_jstf.jpg', 'SmallAnimate_17.jpg', 'mface_8_dots.jpg', 'aircompressor_004.jpg', 'corset_005.jpg', 'hface_2.jpg', 'FFM_057.jpg', 'icecreamcones_002.jpg', 'pface_5_tiny.jpg', 'mface_1_jstf.jpg', 'UFM_53bar.jpg', 'watergun_15.jpg', 'aircompressor_003.jpg', 'Hoof11.jpg', 'mface_10_bars.jpg', 'friday_3_barless.jpg', 'muffins_09.jpg', 'tent_14.jpg', 'humn_8.jpg', 'sewingmachine_001.jpg', 'FFM_084.jpg', 'radio_014.jpg', 'people_11.jpg', 'monk_3.jpg', 'gloves_05.jpg', 'handheldvacuum_003.jpg', 'medpocketcomp.jpg', 'FFM_229.jpg', 'genio_3.jpg', 'humn_8_half.jpg', 'familiarObjects_44.jpg', 'computer_key_012.jpg', 'recordplayer_015.jpg', 'UFH_136.jpg', 'YKDPM.jpg', 'pface_7_eyes.jpg', 'Germanysecondworldwarbill4.jpg', 'hands_14.jpg', 'UFH_132.jpg', 'SmallAnimate_27.jpg', 'UFH_019.jpg', 'pface_6_dots.jpg', 'FH_14.jpg', 'FH_15.jpg', 'FM_47.jpg', 'object_12_tiny.jpg', 'pezdispenser_004.jpg', 'familiar_1.jpg', 'BigAnimate_14.jpg', 'hface_1_blur20.jpg', 'Revlon_Super_Top_Speed_Chrome_Nail_Polish-resized200.jpg', 'Aclock213.jpg', 'UFM_74.jpg', 'balloon_03.jpg', 'FH_234.jpg', 'FFM_006.jpg', 'object_13.jpg', 'laptop_001.jpg', 'familiar_11_half.jpg', 'FH_197.jpg', 'FFM_240.jpg', 'pot25.jpg', 'UFH_108.jpg', 'pface_8_gray.jpg', 'UFH_116.jpg', 'recordplayer_014.jpg', 'chocolate_002.jpg', 'flag_11.jpg', 'hface_10_dots.jpg', 'object_20.jpg', 'FFM_191.jpg', 'friday_3_wbkg.jpg', 'barrel_007.jpg', 'hface_4_blur20.jpg', 'FH_92.jpg', 'bones_001.jpg', 'hookah_002.jpg', 'Hoof13.jpg', 'UFM_40bar.jpg', 'pface_1_hair.jpg', 'bs_bck_9.jpg', 'reportfile_001.jpg', 'FFM_205.jpg', 'profiles_20.jpg', 'bs_bck_4.jpg', 'pTRU1-2898241dt.jpg', 'lock_01.jpg', 'pitcher_011.jpg', 'Gumby_Green-Keychain.jpg', 'domino_14.jpg', 'bench_11.jpg', 'familiarObjects_96.jpg', 'UFM_31.jpg', 'UFH_073.jpg', 'UFM_24barless.jpg', 'roadsign_01.jpg', 'object_9_100white.jpg', 'familiarObjects_51.jpg', 'airplane_008.jpg', 'armyguy_15.jpg', 'cookingpan_05.jpg', 'FH_113.jpg', 'wig_007.jpg', 'macaques_04.jpg', 'familiar_19_bars.jpg', 'object_2_dots.jpg', 'FH_89.jpg', 'VP-Raden-FP-L copy.jpg', 'FFM_091.jpg', 'mface_3_ee.jpg', 'hface_16_bkg_bars.jpg', 'humanfaces_20.jpg', 'grevillea-superb-stamp-1.jpg', 'object_3_bars.jpg', 'leaves_05.jpg', 'mp3player_07.jpg', 'FFM_044.jpg', 'stapler_12.jpg', 'object_8_bkg_bars.jpg', 'BigAnimate_60.jpg', 'profiles_06.jpg', 'FH_134.jpg', 'shoe_105.jpg', 'crown_003.jpg', '26379142.thl.jpg', 'object_2.jpg', 'tape_007.jpg', 'hface_3_gray.jpg', 'pman_3_body.jpg', 'FFM_215.jpg', 'babyplayard_015.jpg', 'FM_37barless.jpg', 'microphone_003.jpg', 'familiarObjects_248.jpg', 'ring_15.jpg', 'pitcher_013.jpg', 'pants_07.jpg', 'FH_168.jpg', 'ketchupbottle_006.jpg', 'mface_10_half.jpg', 'pface_8_dots.jpg', 'UFH_103.jpg', 'swissarmyknife_001.jpg', 'FFM_253.jpg', 'hface_2_hair.jpg', 'bell_01 ...
# ['pman_4_half.jpg', 'mface_1_hair.jpg', 'FH_176.jpg', 'Sony_Bravia_cellphone_1.jpg', 'jumblefaces_06.jpg', 'BigAnimate_39.jpg', 'rock_015.jpg', 'breadloaf_14.jpg', 'OtherGuy_2_wbkg.jpg', 'pezdispenser_002.jpg', 'mface_5_100white.jpg', 'object_6_bars.jpg', 'mface_7_100white.jpg', 'red_3_barless.jpg', 'bonzai_14.jpg', 'pface_2_tiny.jpg', 'mface_4_bkg_bars.jpg', 'hface_10_hair.jpg', 'trumpet33.jpg', 'musicstand_003.jpg', 'Alei22.jpg', 'FFM_046.jpg', 'FH_66.jpg', 'FFM_165.jpg', 'dts_8.jpg', 'FH_7.jpg', 'pie_003.jpg', 'cooler_015.jpg', 'UFH_187.jpg', 'tennisracquet_04.jpg', 'va-eew.jpg', 'object_6_dots.jpg', 'object_12_100white.jpg', 'UFH_170.jpg', 'monk_4.jpg', 'FH_261.jpg', 'familiarObjects_13.jpg', 'UFH_006.jpg', 'Make-Up-Set-Cake.jpg', 'hface_9_half.jpg', 'familiar_16_bkg_bars.jpg', 'trophy_015.jpg', 'weirdT_7.jpg', 'macaques_21.jpg', 'FH_83.jpg', 'waxseal_001.jpg', 'Parth_Portofino_500.jpg', 'hands_19.jpg', 'familar_12.jpg', 'keynew01.jpg', 'FFM_137.jpg', 'ABEARMASK.jpg', 'carabiners_012.jpg', 'pman_9_half.jpg', 'bill_013.jpg', 'familiar_14_gray.jpg', 'soapdispenser_001.jpg', 'FM_83.jpg', 'profiles_09.jpg', 'motorola c115-thumb.jpg', 'familiar_8_bkg.jpg', 'grapes_002.jpg', 'plate_002.jpg', 'pface_3_jstf.jpg', 'SmallAnimate_17.jpg', 'mface_8_dots.jpg', 'aircompressor_004.jpg', 'corset_005.jpg', 'hface_2.jpg', 'FFM_057.jpg', 'icecreamcones_002.jpg', 'pface_5_tiny.jpg', 'mface_1_jstf.jpg', 'UFM_53bar.jpg', 'watergun_15.jpg', 'aircompressor_003.jpg', 'Hoof11.jpg', 'mface_10_bars.jpg', 'friday_3_barless.jpg', 'muffins_09.jpg', 'tent_14.jpg', 'humn_8.jpg', 'sewingmachine_001.jpg', 'FFM_084.jpg', 'radio_014.jpg', 'people_11.jpg', 'monk_3.jpg', 'gloves_05.jpg', 'handheldvacuum_003.jpg', 'medpocketcomp.jpg', 'FFM_229.jpg', 'genio_3.jpg', 'humn_8_half.jpg', 'familiarObjects_44.jpg', 'computer_key_012.jpg', 'recordplayer_015.jpg', 'UFH_136.jpg', 'YKDPM.jpg', 'pface_7_eyes.jpg', 'Germanysecondworldwarbill4.jpg', 'hands_14.jpg', 'UFH_132.jpg', 'SmallAnimate_27.jpg', 'UFH_019.jpg', 'pface_6_dots.jpg', 'FH_14.jpg', 'FH_15.jpg', 'FM_47.jpg', 'object_12_tiny.jpg', 'pezdispenser_004.jpg', 'familiar_1.jpg', 'BigAnimate_14.jpg', 'hface_1_blur20.jpg', 'Revlon_Super_Top_Speed_Chrome_Nail_Polish-resized200.jpg', 'Aclock213.jpg', 'UFM_74.jpg', 'balloon_03.jpg', 'FH_234.jpg', 'FFM_006.jpg', 'object_13.jpg', 'laptop_001.jpg', 'familiar_11_half.jpg', 'FH_197.jpg', 'FFM_240.jpg', 'pot25.jpg', 'UFH_108.jpg', 'pface_8_gray.jpg', 'UFH_116.jpg', 'recordplayer_014.jpg', 'chocolate_002.jpg', 'flag_11.jpg', 'hface_10_dots.jpg', 'object_20.jpg', 'FFM_191.jpg', 'friday_3_wbkg.jpg', 'barrel_007.jpg', 'hface_4_blur20.jpg', 'FH_92.jpg', 'bones_001.jpg', 'hookah_002.jpg', 'Hoof13.jpg', 'UFM_40bar.jpg', 'pface_1_hair.jpg', 'bs_bck_9.jpg', 'reportfile_001.jpg', 'FFM_205.jpg', 'profiles_20.jpg', 'bs_bck_4.jpg', 'pTRU1-2898241dt.jpg', 'lock_01.jpg', 'pitcher_011.jpg', 'Gumby_Green-Keychain.jpg', 'domino_14.jpg', 'bench_11.jpg', 'familiarObjects_96.jpg', 'UFM_31.jpg', 'UFH_073.jpg', 'UFM_24barless.jpg', 'roadsign_01.jpg', 'object_9_100white.jpg', 'familiarObjects_51.jpg', 'airplane_008.jpg', 'armyguy_15.jpg', 'cookingpan_05.jpg', 'FH_113.jpg', 'wig_007.jpg', 'macaques_04.jpg', 'familiar_19_bars.jpg', 'object_2_dots.jpg', 'FH_89.jpg', 'VP-Raden-FP-L copy.jpg', 'FFM_091.jpg', 'mface_3_ee.jpg', 'hface_16_bkg_bars.jpg', 'humanfaces_20.jpg', 'grevillea-superb-stamp-1.jpg', 'object_3_bars.jpg', 'leaves_05.jpg', 'mp3player_07.jpg', 'FFM_044.jpg', 'stapler_12.jpg', 'object_8_bkg_bars.jpg', 'BigAnimate_60.jpg', 'profiles_06.jpg', 'FH_134.jpg', 'shoe_105.jpg', 'crown_003.jpg', '26379142.thl.jpg', 'object_2.jpg', 'tape_007.jpg', 'hface_3_gray.jpg', 'pman_3_body.jpg', 'FFM_215.jpg', 'babyplayard_015.jpg', 'FM_37barless.jpg', 'microphone_003.jpg', 'familiarObjects_248.jpg', 'ring_15.jpg', 'pitcher_013.jpg', 'pants_07.jpg', 'FH_168.jpg', 'ketchupbottle_006.jpg', 'mface_10_half.jpg', 'pface_8_dots.jpg', 'UFH_103.jpg', 'swissarmyknife_001.jpg', 'FFM_253.jpg', 'hface_2_hair.jpg', 'bell_01 ...

# %% [markdown]
# map ANNs' presentation order onto neurons' presentation order (so that then we have everything ordered)
# + compute RDM and store it

# %%
#all_feats = all_feats[mapping, :, :]
RDM_vec = create_RDM(all_feats.T)

# np.savez_compressed(RDM_save_name, RDM_vec)
# Out:
# array([0.87674255, 0.94231483, 0.89238954, 0.86995213, 0.94218925,
#        0.90243311, 0.80311104, 0.78804938, 0.85510519, 0.92680236,
#        0.92788447, 0.92866926, 0.84817898, 0.87856231, 0.79127428])

# %% [markdown]
# do PCA, store it and project features

# %%
pca = PCA(n_components=cfg.n_components)
pca.fit(all_feats)
# joblib.dump(pca, pca_save_name)
all_feats_redu = pca.transform(all_feats)
# np.savez_compressed(feats_save_name, all_feats_redu.T)

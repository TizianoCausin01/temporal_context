# %%
import os, yaml, sys
import numpy as np
import matplotlib.pyplot as plt
import pickle
import cv2
# %matplotlib inline

ENV = os.getenv("MY_ENV", "dev")
with open("../../config.yaml", "r") as f:
    config = yaml.safe_load(f)
paths = config[ENV]["paths"]
sys.path.append(paths["src_path"])
from general_utils.utils import print_wise
from image_processing.utils import read_video

# %%
v = read_video(paths, 1, "anna2_to_paul_10s.mp4")
# Out:
# 09:09:03 - rank 1 anna2_to_paul_10s.mp4 read successfully

# %%
from IPython.display import clear_output
for i in range(v.shape[0]):    
    plt.imshow(v[i, :,:,:])
    plt.axis("off")
    plt.pause(1 / 30)  # assuming 30 FPS
    plt.clf()
    clear_output(wait=True)

cap.release()
plt.close()

# %%
import os, yaml, sys
import numpy as np
import matplotlib.pyplot as plt

ENV = os.getenv("MY_ENV", "dev")
with open("../../config.yaml", "r") as f:
    config = yaml.safe_load(f)
paths = config[ENV]["paths"]
sys.path.append(paths["src_path"])
from general_utils.utils import get_lagplot, get_lagplot_subset, print_wise
from neural_utils.utils import load_monkey_data

# %%
a = np.random.random((30,30))
# Get the indices of the upper triangle (excluding the diagonal)
rows, cols = np.triu_indices(a.shape[0], k=1)  # k=0 includes diagonal, k=1 excludes

# Substitute values, e.g., set upper triangle to 0
a[rows, cols] = 0

# %%
b = get_lagplot_subset(a,range(a.shape[0])[10:15], max_lag=10, min_datapts=1)#, range(0,30))
c = get_lagplot(a, max_lag=10, min_datapts=1)

# %%
plt.plot(b)
plt.plot(c)
plt.legend(["b", "c"])

# %%
import os, yaml, sys
import numpy as np
import matplotlib.pyplot as plt

ENV = os.getenv("MY_ENV", "dev")
with open("../../config.yaml", "r") as f:
    config = yaml.safe_load(f)
paths = config[ENV]["paths"]
sys.path.append(paths["src_path"])
from general_utils.utils import compute_dRSA, spearman

# %%
neu = 20; features = 15; T = 30; trials = 10;
neural_data = np.random.rand(neu, T, trials)
model_data = np.random.rand(features, T, trials)

# %%
dRSA = compute_dRSA(neural_data, model_data, metric_RDM='correlation', metric_RDM_model=None, metric_dRSA=spearman)

# %%
plt.imshow(dRSA)
